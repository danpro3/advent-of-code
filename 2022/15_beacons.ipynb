# %%
# part 1
import re

def merge_ranges(ranges):
    """Merges a set of ranges into a list of non-overlapping ranges."""
    # Sort the ranges by their start values
    ranges.sort(key=lambda x: x[0])
    merged_ranges = []
    current_range = ranges[0]
    for i in range(1, len(ranges)):
        next_range = ranges[i]
        # Check for overlap
        if current_range[1] >= next_range[0]:
            # Merge overlapping ranges
            current_range = (current_range[0], max(current_range[1], next_range[1]))
        else:
            # Add the current range to the merged list
            merged_ranges.append(current_range)
            current_range = next_range
    # Add the last range
    merged_ranges.append(current_range)
    return merged_ranges

# lines = open('inputs/input_15_test.txt','r').read().splitlines()
lines = open('inputs/input_15.txt','r').read().splitlines()
YY = 10 # row of interest
ranges = []
for line in lines:

    S = [int(x) for x in re.findall(r'-?\d+', line)]  # sensor info [sensor:x,y  nearest beacon:x,y]
    # print(S)
    S_range = abs(S[0]-S[2]) + abs(S[3]-S[1])
    reach = S_range - abs(S[1] - YY)
    if reach >= 0: # need to block off some positions
        newrange = [S[0]-reach, S[0]+reach]
        print(f'sensor: {S[0],S[1]}, range: {S_range}, can reach: {reach}, newrange = {newrange}')
        ranges.append(newrange)
        ranges = merge_ranges(ranges)
    print(f'ranges = {ranges}')

# sum the ranges:
sum_ranges = 0
for ranges1 in ranges:
    sum_ranges += ranges1[1] - ranges1[0] + 1

print(f'sum of ranges = {sum_ranges}')
# Out:
# ranges = []
# sensor: (1999258, 1017714), range: 1778016, can reach: 760312, newrange = [1238946, 2759570]
# ranges = [[1238946, 2759570]]
# ranges = [[1238946, 2759570]]
# ranges = [[1238946, 2759570]]
# sensor: (188608, 354698), range: 1972741, can reach: 1618053, newrange = [-1429445, 1806661]
# ranges = [(-1429445, 2759570)]
# ranges = [(-1429445, 2759570)]
# ranges = [(-1429445, 2759570)]
# ranges = [(-1429445, 2759570)]
# sensor: (2533266, 439414), range: 931910, can reach: 492506, newrange = [2040760, 3025772]
# ranges = [(-1429445, 3025772)]
# ranges = [(-1429445, 3025772)]
# ranges = [(-1429445, 3025772)]
# ranges = [(-1429445, 3025772)]
# sensor: (3278267, 201451), range: 424872, can reach: 223431, newrange = [3054836, 3501698]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# ranges = [(-1429445, 3025772), [3054836, 3501698]]
# sensor: (3579002, 1702), range: 817740, can reach: 816048, newrange = [2762954, 4395050]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# ranges = [(-1429445, 4395050)]
# sensor: (3947251, 469499), range: 718192, can reach: 248703, newrange = [3698548, 4195954]
# ranges = [(-1429445, 4395050)]
# sum of ranges = 5824496
