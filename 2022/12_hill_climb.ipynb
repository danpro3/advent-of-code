# %%
# part 1
from heapq import heapify, heappush, heappop

def find_letter(letter):
    idx = filestr.find(letter)
    r,c =  (idx//len(lines[0]), idx%len(lines[0]))
    print(f'{letter} = ({r},{c})')
    return (r,c)

def V(r,c): # return the value of the grid location
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    return alphabet.index(grid[r][c])

def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]

def start_the_todo(S):
    r,c = S
    todo = [] # todo = (row, col, dir)
    # check up
    if r>0 and V(r-1,c) <= V(r,c)+1:
        heappush(todo, (0, r-1, c, 'U'))
    # check down
    if r<Y-1 and V(r+1,c) <= V(r,c)+1:
        heappush(todo, (0, r+1, c, 'D'))
    # check left
    if c>0 and V(r,c-1) <= V(r,c)+1:
        heappush(todo, (0, r, c-1, 'L'))
    # check right
    if c<X-1 and V(r,c+1) <= V(r,c)+1:
        heappush(todo, (0, r, c+1, 'R'))
    heapify(todo)
    return todo

def move(todo):
    dist, r, c, dir = heappop(todo)
    # if we've been here before, end this thread
    key = (r, c, dir)
    if key in cache:
        # print(r,c,dir,'in cache')
        return todo
    else:
        # add this state to the cache
        cache[key] = 0
        cache_grid[r][c] = '#'

    # check up
    if r>0 and V(r-1,c) <= V(r,c)+1:
        heappush(todo, (dist+1, r-1, c, 'U'))
    # check down
    if r<Y-1 and V(r+1,c) <= V(r,c)+1:
        heappush(todo, (dist+1, r+1, c, 'D'))
    # check left
    if c>0 and V(r,c-1) <= V(r,c)+1:
        heappush(todo, (dist+1, r, c-1, 'L'))
    # check right
    if c<X-1 and V(r,c+1) <= V(r,c)+1:
        heappush(todo, (dist+1, r, c+1, 'R'))
    return(todo)

# main
# lines = open('inputs/input_12_test.txt','r').read()
lines = open('inputs/input_12.txt','r').read()
filestr = lines.replace('\n','')
lines = lines.splitlines()


# locations of start and end
S = find_letter('S')
E = find_letter('E')
grid = [[x for x in i] for i in lines]
# print_grid(grid)
grid[S[0]][S[1]] = 'a'
grid[E[0]][E[1]] = 'z'

Y = len(grid)
X = len(grid[0])
cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# start
r,c = [S[0], S[1]]
cache = {}   # list of all places been: (row, col, dir)
todo = start_the_todo(S)

print(todo)
while todo[0][1:3] != E:
    # print(todo[0][1:3])
    # print(todo)
    todo = move(todo)
    # print(f'dist = {todo[0][0]}')

# move to the end
print('top of heap: ',todo[0],'dist',todo[0][0])
dist, r, c, dir = heappop(todo)
# print_grid(cache_grid)
# print(todo)
print(f'total steps = dist+1 = {dist+1}')
# Out:
# S = (20,0)
# E = (20,120)
# [(0, 19, 0, 'U'), (0, 21, 0, 'D'), (0, 20, 1, 'R')]
# top of heap:  (461, 20, 120, 'U') dist 461
# total steps = dist+1 = 462

# %%
import re
def find_letters(letter):
    iter = re.finditer(letter, filestr)
    mlist = [m.start(0) for m in iter]
    startlist = []
    for idx in mlist:
        # print(idx)
        r,c =  (idx//len(lines[0]), idx%len(lines[0]))
        startlist.append((r,c))
    return startlist

# main
# [print(x) for x in lines]
startlist = find_letters(r'[aS]')
print(f'startlist = {startlist}')
print(f'length of startlist = {len(startlist)}')

hikes = []
for startloc in startlist: # loop on start locations
    # print(f'startloc = {startloc}')
    cache = {}   # list of all places been: (row, col, dir)
    todo = start_the_todo(startloc)
    # print(f'todo = {todo}')
    while todo[0][1:3] != E:
        # print(todo[0][1:3])
        # print(todo)
        todo = move(todo)
        # print(f'dist = {todo[0][0]}')

    # move to the end
    print('top of heap: ',todo[0],'dist',todo[0][0])
    dist, r, c, dir = heappop(todo)
    # print_grid(cache_grid)
    print(f'total steps = dist+1 = {dist+1}')
    hikes.append(dist+1)
    print(f'hikes = {hikes}')
    
print(f'shortest hike = {min(hikes)}')
# Out:
# startlist = [(0, 0), (0, 19), (0, 20), (0, 21), (0, 22), (0, 23), (0, 24), (0, 25), (0, 26), (0, 33), (0, 37), (0, 38), (0, 57), (0, 58), (0, 59), (0, 60), (0, 61), (0, 62), (0, 63), (0, 64), (0, 65), (0, 66), (0, 98), (0, 99), (0, 100), (0, 101), (0, 102), (0, 103), (0, 138), (0, 139), (0, 140), (0, 141), (0, 142), (1, 0), (1, 20), (1, 21), (1, 22), (1, 23), (1, 24), (1, 32), (1, 33), (1, 34), (1, 35), (1, 36), (1, 37), (1, 38), (1, 50), (1, 51), (1, 54), (1, 55), (1, 56), (1, 57), (1, 58), (1, 59), (1, 60), (1, 61), (1, 62), (1, 63), (1, 64), (1, 65), (1, 66), (1, 99), (1, 100), (1, 101), (1, 102), (1, 103), (1, 137), (1, 138), (1, 139), (1, 140), (1, 141), (1, 142), (2, 0), (2, 14), (2, 15), (2, 20), (2, 21), (2, 22), (2, 23), (2, 24), (2, 25), (2, 33), (2, 34), (2, 35), (2, 36), (2, 37), (2, 38), (2, 39), (2, 40), (2, 47), (2, 49), (2, 50), (2, 51), (2, 54), (2, 55), (2, 56), (2, 57), (2, 58), (2, 59), (2, 60), (2, 61), (2, 62), (2, 63), (2, 64), (2, 65), (2, 66), (2, 67), (2, 68), (2, 87), (2, 88), (2, 89), (2, 97), (2, 98), (2, 99), (2, 100), (2, 101), (2, 102), (2, 103), (2, 120), (2, 121), (2, 122), (2, 137), (2, 138), (2, 139), (2, 140), (2, 141), (2, 142), (3, 0), (3, 10), (3, 14), (3, 15), (3, 20), (3, 21), (3, 22), (3, 23), (3, 24), (3, 25), (3, 33), (3, 34), (3, 35), (3, 36), (3, 37), (3, 38), (3, 39), (3, 40), (3, 41), (3, 46), (3, 47), (3, 48), (3, 49), (3, 50), (3, 51), (3, 52), (3, 53), (3, 54), (3, 56), (3, 57), (3, 58), (3, 59), (3, 60), (3, 61), (3, 62), (3, 63), (3, 64), (3, 65), (3, 66), (3, 67), (3, 68), (3, 88), (3, 89), (3, 97), (3, 98), (3, 99), (3, 100), (3, 101), (3, 102), (3, 103), (3, 104), (3, 120), (3, 121), (3, 122), (3, 137), (3, 140), (3, 141), (3, 142), (4, 0), (4, 2), (4, 3), (4, 9), (4, 10), (4, 11), (4, 12), (4, 13), (4, 14), (4, 15), (4, 20), (4, 21), (4, 22), (4, 25), (4, 33), (4, 34), (4, 35), (4, 36), (4, 37), (4, 38), (4, 39), (4, 40), (4, 41), (4, 46), (4, 47), (4, 48), (4, 49), (4, 50),