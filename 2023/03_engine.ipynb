# %%
import re
import math

sum_part_numbers = 0
sum_gears = 0;
gears = []

with open("03__input.txt", "r") as file:
   filestr = file.read()
print(filestr)
numcols = filestr.find('\n') + 1  # number of columns in the engine schematic
filestr = filestr.replace('\n','.')
numrows = len(filestr) // numcols
print('numrows =',numrows,', numcols = ',numcols)
number_list = re.findall('\d+',filestr)
print(number_list)
number_idx = [(m.start(0), m.end(0)-1) for m in re.finditer('\d+', filestr)]
print(number_idx)
for i,num in enumerate(number_list):
   valid_number = False
   col_start = number_idx[i][0] % numcols
   col_end = number_idx[i][1] % numcols
   row = number_idx[i][0] // numcols
   # print('row = ',row,', column from',col_start,'to',col_end)
   
   # check same row
   if col_start > 0:
      # print(number_list[i], filestr[number_idx[i][0]-1])
      if re.match('[^.]',filestr[number_idx[i][0]-1]):
         valid_number = True
         symbols = filestr[number_idx[i][0]-1]
         print(num,'validated to the left with',symbols)
         if symbols == '*':
            gears.append((number_idx[i][0]-1,int(num)))
   if col_end < numcols-1:
      # print(number_list[i], filestr[number_idx[i][1]+1])
      if re.match('[^.]',filestr[number_idx[i][1]+1]):
         valid_number = True
         symbols = filestr[number_idx[i][1]+1]
         print(num,'validated to the right with',symbols)
         if symbols == '*':
            gears.append((number_idx[i][1]+1,int(num)))

   # check above
   if row > 0:
      # print(number_list[i],'above = ',filestr[number_idx[i][0]-numcols:number_idx[i][1]-numcols+1])
      if re.findall('[^.]',filestr[number_idx[i][0]-numcols:number_idx[i][1]-numcols+1]):
         valid_number = True
         symbols = filestr[number_idx[i][0]-numcols:number_idx[i][1]-numcols+1]
         print(num,'validated above with',symbols)
         gears_ind = symbols.find('*')
         if gears_ind > -1:
            gears.append((number_idx[i][0]-numcols+gears_ind,int(num)))

      if col_start > 0:  # check upper left
         # print(number_list[i],'upper left corner = ',filestr[number_idx[i][0]-numcols-1],'index =',number_idx[i][0]-numcols-1)
         if re.match('[^.]',filestr[number_idx[i][0]-numcols-1]):
            valid_number = True
            symbols = filestr[number_idx[i][0]-numcols-1]
            print(num,'validated to the upper left with',symbols)
            if symbols == '*':
               gears.append((number_idx[i][0]-numcols-1,int(num)))

      if col_end < numcols-1: # check upper right
         if re.match('[^.]',filestr[number_idx[i][1]-numcols+1]):
            valid_number = True
            symbols = filestr[number_idx[i][1]-numcols+1]
            print(num,'validated to the upper right with',symbols)
            if symbols == '*':
               gears.append((number_idx[i][1]-numcols+1,int(num)))

   # check below
   if row < numrows - 1:
      if re.findall('[^.]',filestr[number_idx[i][0]+numcols:number_idx[i][1]+numcols+1]):
         valid_number = True
         symbols = filestr[number_idx[i][0]+numcols:number_idx[i][1]+numcols+1]
         print(num,'validated below with',symbols)
         gears_ind = symbols.find('*')
         if gears_ind > -1:
            gears.append((number_idx[i][0]+numcols+gears_ind,int(num)))

      if col_start > 0:  # check lower left
         if re.match('[^.]',filestr[number_idx[i][0]+numcols-1]):
            valid_number = True
            symbols = filestr[number_idx[i][0]+numcols-1]
            print(num,'validated to the lower left with',symbols)
            if symbols == '*':
               gears.append((number_idx[i][0]+numcols-1,int(num)))

      if col_end < numcols-1: # check lower right
# 830 validated to the lower right with *
# 59 validated below with .*
# 955 validated to the lower right with $
# 663 validated to the lower right with *
# 895 validated to the lower left with *
# 899 validated below with *..
# 826 validated below with ..*
# 220 validated to the lower left with -
# 488 validated below with ..*
# 939 validated below with &..
# 976 validated above with .*.
# 679 validated to the lower left with =
# 461 validated below with ./.
# 7 validated to the upper right with *
# 350 validated above with +..
# 33 validated above with .*
# 380 validated below with ..*
# 151 validated to the upper right with *
# 897 validated to the upper left with *
# 105 validated to the upper left with *
# 418 validated to the upper left with *
# 481 validated to the upper right with *
# 992 validated above with .%.
# 701 validated to the lower right with *
# 508 validated above with ..$
# 578 validated above with .$.
# 259 validated above with #..
# 331 validated above with .*.
# 795 validated to the lower left with *
# 945 validated below with -..
# 79 validated below with .@
# 868 validated above with ..#
# 17 validated to the right with *
# 348 validated to the lower left with *
# 441 validated to the right with *
# 852 validated to the left with *
# 200 validated to the left with *
# 311 validated above with *..
# 63 validated below with *.
# 452 validated below with *..
# 323 validated to the upper left with *
# 778 validated to the left with #
# 674 validated to the lower right with *
# 696 validated below with *..
# 372 validated to the lower left with *
# 209 validated to the upper right with *
# 7 validated to the lower left with *
# 233 validated below with ..*
# 755 validated to the upper left with *
# 272 validated below with $..
# 697 validated to the lower left with /
# 682 validated to the upper right with *
# 949 validated to the upper right with =
# 607 validated to the upper right with *
# 899 validated above with *..
# 679 validated below with ..*
# 527 validated below with *..
# 331 validated above with *..
# 788 validated to the lower left with *
# 43 validated above with *.
# 89 validated to the upper left with *
# 367 validated below with *..
# 328 validated below with ..*
# 69 validated to the upper right with &
# 717 validated to the upper right with *
# 60 validated to the upper right with *
# 728 validated to the lower left with *
# 264 validated below with *..
# 119 validated to the upper left with &
# 253 validated above with ..%
# 626 validated below with @..
# 129 validated above with *..
# 274 validated to the lower left with *
# 97 validated below with /.
# 679 validated to the upper right with *
# 752 validated below with .*.
# 360 validated above with *..
# 471 validated above with .*.
# 573 validated to the right with -
# 702 validated below with ..*
# 772 validated to the lower left with /
# 259 validated below with *..
# 430 validated above with *..
# 136 validated above with .*.
# 742 validated above with ..*
# 543 validated above with *..
# 852 validated above with ./.
# 775 validated below with *..
# 643 validated to the lower left with *
# 455 validated to the upper right with *
# 41 validated above with .*
# 535 validated below with %..
# 340 validated to the upper right with /
# 103 validated to the upper right with *
# 51 validated to the right with *
# 74 validated to the lower left with =
# 438 validated to the upper left with *
# 776 validated to the lower left with *
# 23 validated to the right with *
# 663 validated to the lower left with =
# 806 validated to the upper right with -
# 990 validated below with *..
# 427 validated to the upper left with *
# 924 validated to the upper right with $
# 530 validated below with .*.
# 968 validated above with ..+
# 480 validated to the lower left with *
# 914 validated to the left with @
# 406 validated to the upper right with *
# 201 validated above with ..#
# 592 validated above with ..*
# 70 validated to the upper right with *
# 894 validated to the upper left with *
# 247 validated below with *..
# 513 validated to the right with +
# 367 validated to the upper right with %
# 299 validated to the left with $
# 698 validated above with *..
# 199 validated below with ..*
# 223 validated to the upper left with /
# 783 validated to the upper left with *
# 448 validated to the lower right with *
# 440 validated to the lower right with *
# 889 validated below with .*.
# 715 validated above with -..
# 351 validated above with ../
# 39 validated to the lower right with @
# 138 validated to the lower right with %
# 766 validated to the left with /
# 152 validated to the upper right with *
# 599 validated above with ..*
# 820 validated below with =..
# 10 validated to the right with *
# 43 validated to the left with *
# 670 validated to the upper right with *
# 87 validated to the left with $
# 100 validated to the right with *
# 244 validated to the left with *
# 706 validated to the left with @
# 668 validated below with ..*
# 319 validated to the right with #
# 831 validated above with .*.
# 736 validated above with .*.
# 693 validated to the lower left with -
# 321 validated to the right with %
# 930 validated to the right with #
# 493 validated to the lower left with &
# 569 validated to the lower right with *
# 914 validated above with .@.
# 764 validated below with ..+
# 9 validated above with /
# 378 validated to the right with $
# 854 validated below with ..*
# 505 validated above with ..@
# 124 validated above with ..*
# 12 validated below with .*
# 117 validated below with .*.
# 591 validated to the left with *
# 76 validated below with ./
# 133 validated above with ..=
# 141 validated above with &..
# 770 validated to the upper left with %
# 874 validated below with ..+
# 684 validated to the left with /
# 778 validated above with /..
# 954 validated above with *..
# 397 validated to the left with *
# 394 validated to the upper right with *
# 614 validated to the upper left with *
# 307 validated to the right with *
# 74 validated to the left with *
# 457 validated below with .*.
# 514 validated above with @..
# 335 validated to the right with *
# 25 validated to the left with *
# 31 validated to the lower right with *
# 719 validated below with ..*
# 6 validated below with *
# 878 validated below with ..*
# 86 validated to the right with *
# 269 validated above with -..
# 480 validated below with *..
# 140 validated below with ..*
# 947 validated above with .$.
# 972 validated below with .+.
# 364 validated to the right with *
# 274 validated to the left with *
# 501 validated to the right with -
# 285 validated above with ..*
# 6 validated below with *
# 335 validated to the upper right with *
# 167 validated to the upper left with *
# 18 validated above with .*
# 332 validated to the upper left with &
# 741 validated below with .$.
# 127 validated above with .*.
# 246 validated above with ..*
# 616 validated to the lower right with *
# 752 validated to the right with *
# 276 validated to the left with *
# 470 validated above with ..*
# 848 validated below with ..*
# 599 validated to the lower left with -
# 779 validated above with ..*
# 539 validated below with .*.
# 961 validated to the lower left with -
# 204 validated below with &..
# 201 validated to the right with *
# 491 validated to the lower right with $
# 521 validated to the lower left with *
# 94 validated to the left with *
# 163 validated to the upper right with *
# 285 validated to the right with /
# 51 validated above with =.
# 99 validated to the right with *
# 474 validated below with .*.
# 945 validated to the lower right with *
# 839 validated to the upper right with -
# 140 validated to the upper left with *
# 201 validated to the upper left with %
# 795 validated to the upper right with *
# 539 validated below with .*.
# 500 validated above with ..*
# 662 validated above with &..
# 421 validated to the upper left with *
# 459 validated above with *..
# 407 validated to the left with *
# 471 validated above with $..
# 110 validated above with *..
# 730 validated above with .*.
# 551 validated to the upper right with /
# 509 validated below with =..
# 824 validated to the lower left with %
# 230 validated to the upper right with /
# 569 validated to the lower left with *
# 48 validated to the right with =
# 565 validated to the right with =
# 320 validated to the left with &
# 983 validated above with .%.
# 155 validated below with *..
# 54 validated to the lower left with @
# 972 validated below with ..-
# 146 validated to the lower left with -
# 49 validated to the lower right with *
# 433 validated to the lower left with *
# 137 validated above with ..+
# 436 validated above with ..*
# 451 validated to the upper right with @
# 328 validated to the upper left with /
# 568 validated to the right with -
# 552 validated to the right with %
# 957 validated below with *..
# 93 validated to the upper right with *
# 74 validated to the upper left with %
# 285 validated below with ./.
# 565 validated above with ..@
# 693 validated to the lower left with *
# 443 validated below with .*.
# 58 validated to the left with @
# 362 validated below with ..=
# 383 validated to the upper right with *
# 583 validated to the upper left with *
# 542 validated above with ./.
# 38 validated to the upper right with #
# 890 validated below with ..&
# 506 validated to the upper left with *
# 477 validated to the lower right with *
# 612 validated above with .*.
# 459 validated below with .$.
# 462 validated above with .*.
# 663 validated to the upper right with *
# 125 validated to the upper right with &
# 720 validated to the lower left with =
# 355 validated to the lower left with *
# 253 validated to the lower right with *
# 904 validated to the lower left with $
# 30 validated to the left with *
# 284 validated above with .*.
# 383 validated to the lower left with @
# 999 validated below with #..
# 240 validated below with .*.
# 295 validated to the right with *
# 681 validated to the left with *
# 846 validated below with .%.
# 53 validated to the upper left with *
# 806 validated below with *..
# 793 validated below with .*.
# 646 validated above with ..#
# 626 validated below with *..
# 76 validated to the left with /
# 479 validated below with .%.
# 558 validated below with ../
# 892 validated to the upper right with &
# 885 validated to the upper left with &
# 804 validated to the lower right with /
# 587 validated to the right with *
# 340 validated above with ..%
# 635 validated to the lower right with *
# 213 validated to the upper left with *
# 512 validated above with *..
# 551 validated to the lower right with *
# 910 validated to the upper left with *
# 361 validated above with -..
# 270 validated to the right with *
# 328 validated above with .$.
# 853 validated to the upper right with *
# 985 validated above with ..@
# 965 validated to the lower right with *
# 232 validated below with ..*
# 501 validated to the right with @
# 213 validated to the upper left with *
# 412 validated to the right with $
# 631 validated above with ..*
# 916 validated to the lower right with -
# 254 validated to the lower left with *
# 284 validated above with ..*
# 252 validated below with .*.
# 695 validated to the lower right with *
# 872 validated to the right with *
# 876 validated to the left with *
# 622 validated below with ..*
# 575 validated to the lower left with *
# 851 validated to the right with *
# 910 validated above with #..
# 395 validated above with .*.
# 717 validated to the left with *
# 248 validated above with *..
# 91 validated to the lower right with *
# 390 validated below with ..=
# 497 validated below with ..*
# 297 validated to the upper right with *
# 873 validated below with .=.
# 946 validated above with *..
# 8 validated to the upper right with *
# 647 validated to the lower left with *
# 424 validated below with ..*
# 108 validated to the upper right with *
# 686 validated above with .*.
# 418 validated above with ..@
# 131 validated above with .*.
# 327 validated above with &..
# 561 validated to the lower right with *
# 343 validated to the right with *
# 731 validated to the upper right with *
# 938 validated to the upper left with *
# 256 validated below with .*.
# 811 validated above with ..*
# 680 validated below with *..
# 167 validated below with *..
# 601 validated to the lower left with *
# 142 validated to the right with *
# 108 validated above with .*.
# 653 validated to the upper left with =
# 879 validated below with =..
# 699 validated above with ..*
# 695 validated above with #..
# 870 validated to the lower right with *
# 526 validated to the upper left with *
# 8 validated to the left with *
# 54 validated to the lower left with *
# 311 validated below with ..*
# 320 validated to the upper right with @
# 619 validated above with *..
# 495 validated above with %..
# 375 validated above with *..
# 926 validated to the upper left with *
# 914 validated below with *..
# 236 validated above with $..
# 444 validated to the upper right with *
# 613 validated to the left with @
# 450 validated to the right with *
# 786 validated to the lower right with *
# 625 validated to the lower left with *
# 804 validated below with *..
# 850 validated to the lower right with *
# 674 validated to the upper left with *
# 305 validated above with .$.
# 593 validated above with .*.
# 517 validated to the upper left with *
# 155 validated to the upper left with *
# 646 validated to the right with *
# 239 validated to the left with *
# 286 validated below with =..
# 96 validated below with .&
# 264 validated above with *..
# 471 validated below with ..+
# 314 validated to the right with *
# 901 validated to the left with *
# 879 validated below with ..*
# 419 validated to the upper right with +
# 820 validated below with .*.
# 163 validated above with .*.
# 586 validated below with .*.
# 331 validated below with ..%
# 637 validated below with .$.
# 126 validated below with ./.
# 147 validated to the lower right with @
# 650 validated below with ..*
# 315 validated above with .*.
# 392 validated above with .*.
# 34 validated below with .*
# 752 validated below with ..#
# 161 validated to the lower left with *
# 30 validated to the lower right with =
# 970 validated above with *..
# 412 validated to the right with #
# 569 validated to the lower right with *
# 464 validated below with .$.
# 275 validated above with ..*
# 126 validated to the right with *
# 506 validated to the left with *
# 168 validated to the right with -
# 570 validated above with ..-
# 914 validated above with .@.
# 388 validated below with .*.
# 274 validated below with .$.
# 263 validated above with ..*
# 130 validated to the upper left with &
# 2 validated to the lower left with %
# 21 validated to the right with +
# 268 validated above with *..
# 776 validated to the right with =
# 6 validated below with -
# 759 validated to the upper right with *
# 283 validated below with ..*
# 309 validated to the upper right with %
# 682 validated below with ..@
# 446 validated to the lower left with +
# 284 validated to the left with %
# 119 validated above with ..*
# 622 validated below with *..
# 929 validated to the lower left with *
# 178 validated to the lower left with +
# 141 validated to the right with /
# 650 validated to the left with /
# 440 validated above with ..#
# 335 validated to the upper left with *
# 804 validated to the upper right with +
# 968 validated above with ./.
# 976 validated to the right with *
# 421 validated below with ..-
# 431 validated below with .*.
# 880 validated to the right with @
# 871 validated to the lower left with *
# 30 validated below with &.
# 249 validated above with *..
# 134 validated below with ..*
# 95 validated to the upper right with $
# 856 validated below with -..
# 353 validated below with *..
# 94 validated to the upper right with *
# 963 validated to the lower left with *
# 989 validated below with &..
# 522 validated to the right with +
# 226 validated to the upper right with *
# 436 validated to the upper left with *
# 905 validated below with ..&
# 347 validated to the upper right with *
# 396 validated to the upper left with *
# 707 validated below with .*.
# 511 validated below with /..
# 342 validated above with ..*
# 936 validated to the right with *
# 299 validated to the upper left with *
# 217 validated below with *..
# 478 validated above with /..
# 931 validated to the upper right with *
# 457 validated to the upper left with *
# 62 validated above with $.
# 391 validated to the upper right with *
# 884 validated to the right with *
# 370 validated to the upper left with *
# 483 validated above with *..
# 965 validated to the lower right with *
# 992 validated to the upper left with *
# 371 validated to the right with *
# 771 validated to the left with *
# 37 validated below with *.
# 382 validated above with .*.
# 990 validated to the upper left with *
# 391 validated to the lower left with *
# 852 validated below with .@.
# 753 validated above with ..*
# 935 validated to the left with +
# 677 validated above with .*.
# 164 validated above with &..
# 883 validated to the lower right with *
# 325 validated below with *..
# 951 validated to the lower left with *
# 433 validated above with ..*
# 944 validated to the left with *
# 753 validated below with .*.
# 344 validated to the upper right with *
# 829 validated below with ..*
# 429 validated below with *..
# 34 validated to the left with *
# 329 validated above with ..%
# 421 validated to the upper right with *
# 675 validated below with *..
# 512 validated below with *..
# 999 validated below with .%.
# 102 validated above with *..
# 398 validated above with .*.
# 640 validated to the upper left with %
# 401 validated to the upper right with *
# 310 validated below with *..
# 452 validated below with =..
# 269 validated to the upper right with *
# 9 validated below with #
# 705 validated above with ..*
# 782 validated to the lower left with *
# 615 validated to the lower right with *
# 734 validated to the lower left with *
# 661 validated above with *..
# 14 validated above with .*
# 586 validated to the lower right with *
# 623 validated to the upper left with -
# 324 validated below with ..*
# 601 validated to the upper left with *
# 165 validated below with ..*
# 861 validated to the upper right with *
# 463 validated to the upper left with /
# 361 validated to the right with *
# 906 validated above with ..%
# 897 validated to the lower right with *
# 716 validated to the upper left with @
# 118 validated below with ..+
# 728 validated to the upper right with #
# 395 validated to the right with #
# 443 validated above with ..*
# 829 validated to the upper left with *
# 390 validated to the right with -
# 399 validated above with .*.
# 813 validated above with #..
# 176 validated above with .*.
# 846 validated to the lower left with *
# 719 validated above with ..+
# 132 validated to the lower right with *
# 334 validated to the lower left with *
# 20 validated to the lower right with *
# 51 validated to the upper left with *
# 278 validated above with ..$
# 958 validated below with *..
# 183 validated to the right with *
# 427 validated to the lower left with *
# 766 validated to the lower left with *
# 914 validated below with .*.
# 282 validated to the lower right with /
# 674 validated above with ..%
# 344 validated to the upper right with *
# 249 validated above with ..*
# 445 validated below with .#.
# 770 validated above with .*.
# 67 validated above with .=
# 301 validated to the lower left with =
# 295 validated to the right with *
# 715 validated below with ..*
# 390 validated above with ..*
# 424 validated below with .*.
# 541 validated to the upper left with &
# 160 validated to the lower right with *
# 580 validated to the lower left with *
# 677 validated to the left with *
# 394 validated to the upper right with *
# 327 validated to the upper left with *
# 739 validated to the lower right with /
# 179 validated to the lower right with *
# 360 validated to the lower left with *
# 954 validated to the left with -
# 406 validated to the upper right with *
# 765 validated below with -..
# 930 validated above with .*.
# 370 validated above with *..
# 979 validated above with =..
# 379 validated below with *..
# 415 validated above with %..
# 318 validated to the lower right with *
# 284 validated above with ..%
# 440 validated to the lower left with *
# 157 validated to the lower left with *
# 579 validated to the upper right with *
# 550 validated to the upper left with *
# 747 validated below with ..*
# 240 validated to the upper right with %
# 642 validated to the left with *
# 84 validated above with /.
# 331 validated below with .*.
# 2 validated to the right with *
# 582 validated to the lower right with *
# 246 validated above with ..*
# 167 validated below with @..
# 704 validated to the upper left with @
# 763 validated below with .*.
# 999 validated above with *..
# 781 validated to the upper right with %
# 109 validated to the left with -
# 484 validated above with .=.
# 632 validated to the upper right with *
# 488 validated to the upper left with =
# 954 validated to the left with $
# 779 validated above with .*.
# 232 validated below with ..*
# 149 validated to the upper right with *
# 27 validated above with .%
# ...
# 227 validated to the right with *
# 906 validated to the upper right with $
# 70 validated above with .*
# 957 validated to the upper right with *
# 657 validated below with ..*
# 81 validated above with .=
# 813 validated to the upper right with *
# 179 validated to the upper left with *
# 901 validated above with ..=
# 592 validated below with *..
# 7 validated to the upper left with *
# 127 validated to the lower left with *
# 692 validated to the left with $
# 207 validated to the upper right with *
# 91 validated to the upper right with $
# 784 validated above with ..*
# 872 validated below with .*.
# 756 validated below with ..*
# 322 validated below with *..
# 19 validated to the left with *
# 749 validated to the lower right with *
# 624 validated to the upper left with $
# 694 validated below with *..
# 858 validated above with .*.
# 512 validated below with .*.
# 598 validated above with *..
# 352 validated above with .*.
# 934 validated below with .%.
# 126 validated to the upper right with &
# 351 validated below with ..*
# 40 validated below with *.
# 616 validated to the upper right with *
# 153 validated below with .*.
# 661 validated to the left with *
# 823 validated below with *..
# 829 validated to the upper right with +
# 346 validated to the lower left with *
# 821 validated to the lower left with *
# 826 validated above with .*.
# 304 validated to the upper right with *
# 115 validated above with ..*
# 622 validated to the upper right with *
# 606 validated to the upper left with *
# 186 validated below with ..*
# 813 validated above with .*.
# 716 validated to the right with @
# 372 validated above with *..
# 300 validated to the lower left with *
# 489 validated to the upper left with *
# 108 validated to the lower left with *
# 770 validated above with ../
# 919 validated below with ..*
# 782 validated to the upper right with *
# 912 validated to the lower left with *
# 485 validated to the left with %
# 208 validated to the lower left with *
# 220 validated below with +..
# 853 validated to the lower left with *
# 308 validated below with ./.
# 269 validated to the lower left with =
# 539 validated above with .@.
# 2 validated to the upper right with *
# 941 validated to the lower left with *
# 660 validated below with *..
# 532 validated to the upper right with *
# 246 validated to the upper right with *
# 980 validated to the lower right with *
# 357 validated to the right with *
# 32 validated above with .*
# 164 validated below with /..
# 15 validated above with .*
# 479 validated below with *..
# 855 validated above with *..
# 415 validated above with /..
# 305 validated below with +..
# 649 validated below with ..*
# 633 validated to the lower right with *
# 925 validated below with @..
# 634 validated to the lower left with -
# 121 validated above with =..
# 355 validated above with .*.
# 578 validated to the upper left with *
# 14 validated to the right with *
# 422 validated to the lower left with *
# 543 validated above with #..
# 297 validated above with .*.
# 429 validated above with .+.
# 142 validated to the upper right with -
# 960 validated to the lower right with *
# 536 validated to the upper left with *
# 592 validated to the right with #
# 9 validated to the upper left with *
# 515 validated to the lower left with *
# 434 validated above with .*.
# 908 validated above with .*.
# 189 validated to the lower right with $
# 430 validated to the upper left with -
# 332 validated above with ..+
# 722 validated below with ..*
# 450 validated to the upper left with *
# 139 validated below with &..
# 259 validated to the upper right with *
# 39 validated below with ./
# 33 validated below with .*
# 159 validated to the upper left with -
# 925 validated above with .#.
# 743 validated to the lower left with *
# 414 validated below with *..
# 437 validated to the left with =
# 58 validated below with .=
# 475 validated above with .*.
# 227 validated to the right with %
# 217 validated below with .%.
# 506 validated above with .*.
# 63 validated below with .*
# 993 validated below with .*.
# 166 validated above with *..
# 293 validated above with ./.
# 977 validated to the right with +
# 498 validated above with &..
# 834 validated to the lower right with *
# 455 validated to the lower left with @
# 981 validated above with *..
# 991 validated below with .#.
# 636 validated to the upper right with -
# 728 validated to the lower right with $
# 205 validated above with ..%
# 528 validated to the upper right with *
# 226 validated above with ..%
# 664 validated to the lower right with *
# 9 validated to the lower left with *
# 9 validated above with *
# 494 validated below with ..*
# 272 validated above with *..
# 725 validated to the right with *
# 775 validated to the lower right with *
# 854 validated below with .*.
# 226 validated to the lower right with *
# 243 validated to the lower left with *
# 832 validated above with ..*
# 637 validated to the right with *
# 73 validated to the left with *
# 165 validated to the lower left with $
# 340 validated to the right with +
# 548 validated below with +..
# 405 validated to the upper left with *
# 768 validated to the upper left with $
# 81 validated to the lower left with &
# 10 validated below with .*
# 787 validated below with ..*
# 918 validated below with .@.
# 145 validated above with .@.
# 265 validated to the upper left with *
# 110 validated below with .=.
# 45 validated above with .*
# 90 validated to the upper left with *
# 299 validated below with .*.
# 452 validated to the left with -
# 108 validated to the lower right with *
# 305 validated to the lower left with *
# 894 validated below with .-.
# 121 validated below with ..*
# 69 validated to the upper right with $
# 236 validated to the upper right with *
# 97 validated to the upper right with *
# 348 validated below with @..
# 709 validated to the upper left with +
# 411 validated below with .@.
# 135 validated to the upper right with *
# 738 validated below with .*.
# 634 validated to the right with *
# 429 validated to the lower left with -
# 217 validated to the left with %
# 119 validated above with -..
# 47 validated to the upper right with =
# 923 validated below with ..%
# 606 validated below with ..$
# 960 validated below with /..
# 744 validated to the upper left with %
# 215 validated to the lower right with *
# 512 validated below with *..
# 950 validated above with +..
# 444 validated to the lower left with &
# 833 validated above with ..*
# 813 validated below with #..
# 400 validated below with ..-
# 362 validated to the lower left with *
# 898 validated to the lower left with *
# 732 validated below with #..
# 965 validated below with %..
# 584 validated above with &..
# 995 validated above with .%.
# 64 validated below with -.
# 265 validated above with #..
# 781 validated to the lower left with *
# 376 validated below with ..*
# 320 validated above with ..*
# 998 validated above with ..*
# 450 validated below with ..*
# 304 validated to the lower left with %
# 966 validated to the upper left with *
# 875 validated to the upper right with *
# 981 validated below with *..
# 742 validated to the right with *
# 276 validated to the left with *
# 541 validated to the lower left with *
# 219 validated to the lower right with *
# 279 validated to the lower left with *
# 164 validated to the upper left with $
# 551 validated below with -..
# 717 validated to the left with %
# 786 validated below with +..
# 163 validated to the upper left with *
# 915 validated to the upper right with *
# 960 validated above with ..*
# 509 validated below with .&.
# 135 validated to the right with *
# 539 validated to the lower right with *
# 666 validated to the lower left with $
# 699 validated to the lower left with *
# 179 validated above with .*.
# 612 validated above with $..
# 734 validated to the left with =
# 545 validated above with *..
# 88 validated to the upper right with %
# 392 validated to the lower left with *
# 46 validated below with ./
# 483 validated to the right with =
# 548 validated below with .*.
# 135 validated to the upper right with %
# 413 validated below with .*.
# 620 validated to the left with #
# 530 validated to the lower left with =
# 484 validated below with .=.
# 741 validated below with *..
# 444 validated above with &..
# 150 validated to the upper right with *
# 928 validated to the lower right with #
# 858 validated to the upper right with %
# 562 validated to the upper right with *
# 571 validated to the upper left with *
# 117 validated to the right with @
# 195 validated above with ..*
# 896 validated below with ..#
# 662 validated below with ..*
# 388 validated above with .*.
# 320 validated to the upper left with *
# 166 validated to the lower right with *
# 159 validated below with ..%
# 487 validated below with .*.
# 260 validated below with .*.
# 713 validated to the upper right with *
# 347 validated to the lower right with *
# 657 validated to the upper left with /
# 837 validated to the upper left with -
# 273 validated to the lower right with @
# 228 validated to the upper right with *
# 370 validated to the left with *
# 764 validated below with .+.
# 654 validated above with *..
# 679 validated below with .*.
# 918 validated above with .*.
# 681 validated to the upper right with *
# 461 validated below with ..+
# 776 validated to the lower right with *
# 737 validated to the upper right with /
# 859 validated to the lower left with &
# 881 validated to the right with #
# 625 validated to the upper left with -
# 57 validated below with *.
# 887 validated below with .-.
# 911 validated to the left with #
# 46 validated to the right with *
# 72 validated above with .*
# 102 validated to the upper left with $
# 651 validated below with $..
# 530 validated to the left with *
# 667 validated above with $..
# 850 validated above with .*.
# 829 validated to the right with *
# 869 validated to the right with %
# 298 validated to the lower right with *
# 925 validated to the upper left with *
# 352 validated to the right with *
# 6 validated to the lower right with *
# 41 validated to the lower left with *
# 160 validated below with &..
# 72 validated to the lower right with *
# 878 validated to the upper left with *
# 1 validated to the upper right with *
# 738 validated to the lower right with *
# 926 validated to the left with *
# 279 validated below with ..*
# 721 validated to the upper left with *
# 694 validated below with ..-
# 799 validated above with .+.
# 878 validated to the upper right with *
# 219 validated to the lower left with *
# 482 validated below with ..*
# 368 validated to the right with $
# 604 validated below with -..
# 583 validated to the right with *
# 506 validated to the left with *
# 740 validated below with ./.
# 347 validated to the upper left with *
# 576 validated to the upper right with +
# 498 validated above with .*.
# 478 validated to the upper left with /
# 974 validated below with %..
# 320 validated to the lower right with *
# 979 validated to the left with *
# 863 validated to the upper left with *
# 497 validated above with ..*
# 111 validated below with ..*
# 538 validated to the lower right with *
# 7 validated to the upper right with &
# 455 validated to the lower left with *
# 223 validated to the lower left with #
# 939 validated to the upper right with *
# 673 validated to the upper left with =
# 559 validated to the right with -
# 644 validated below with *..
# 669 validated to the right with +
# 1 validated below with *
# 782 validated above with .*.
# 865 validated to the upper left with *
# 779 validated below with .*.
# 937 validated below with *..
# 312 validated to the upper left with =
# 489 validated above with *..
# 571 validated above with ..&
# 69 validated to the upper right with #
# 169 validated above with *..
# 919 validated above with .*.
# 808 validated below with ..*
# 335 validated above with ./.
# 24 validated to the right with *
# 896 validated to the left with *
# 233 validated above with *..
# 553 validated above with *..
# 198 validated to the right with =
# 450 validated to the lower left with *
# 661 validated above with ..*
# 15 validated to the upper right with *
# 575 validated to the left with -
# 919 validated to the right with *
# 492 validated to the upper right with *
# 301 validated to the upper left with -
# 866 validated to the left with /
# 470 validated to the upper left with *
# 299 validated above with .*.
# 27 validated above with .%
# 639 validated to the upper right with *
# 136 validated to the upper left with *
# Sum of part numbers =  521515
# [(156, 830), (169, 59), (185, 663), (240, 895), (248, 899), (268, 826), (377, 488), (156, 976), (169, 7), (185, 33), (481, 380), (210, 151), (210, 897), (240, 105), (248, 418), (268, 481), (600, 701), (377, 331), (677, 795), (632, 17), (783, 348), (665, 441), (665, 852), (725, 200), (600, 311), (887, 63), (905, 452), (632, 323), (932, 674), (961, 696), (966, 372), (725, 209), (1043, 7), (1052, 233), (783, 755), (834, 682), (887, 607), (905, 899), (1200, 679), (1202, 527), (932, 331), (1231, 788), (961, 43), (966, 89), (1277, 367), (1287, 328), (1043, 717), (1052, 60), (1398, 728), (1405, 264), (1202, 129), (1489, 274), (1231, 679), (1521, 752), (1277, 360), (1287, 471), (1598, 702), (1655, 259), (1390, 430), (1398, 136), (1403, 742), (1405, 543), (1743, 775), (1760, 643), (1489, 455), (1521, 41), (1598, 103), (1760, 51), (1655, 438), (1950, 776), (1820, 23), (2002, 990), (1743, 427), (2049, 530), (2108, 480), (1950, 406), (2002, 592), (2017, 70), (2017, 894), (2308, 247), (2049, 698), (2342, 199), (2108, 783), (2422, 448), (2491, 440), (2495, 889), (2308, 152), (2342, 599), (2556, 10), (2556, 43), (2422,