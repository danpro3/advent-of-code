# %%
# part 1
def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]


def move(todo):
    steps, r, c, dir, path = todo.pop(0)
    # print(steps,r,c)
    # if we've been here before, end this thread
    if (steps,r,c,dir) in cache:
        # print(r,c,dir,'in cache')
        return todo
    else:
        # add this state to the cache
        # cache[state] = 0
        cache[(steps,r,c,dir)] = 0

    if r == X-1:
        print('finished. r,c =',r,c,'steps =',steps)
        all_hikes.append(steps)
        path.pop(0)
        all_paths.append(path)        
        return todo
    # check up
    if dir != 'S' and r > 0 and grid[r-1][c] in '.^':
        if (steps+1, r-1, c) not in cache:
            path2 = path[:]
            path2.append((r-1,c))
            todo.insert(0,(steps+1, r-1, c, 'N', path2))
    # check right
    if dir != 'W' and c < X-1 and grid[r][c+1] in '.>':
        if (steps+1, r, c+1) not in cache:
            path2 = path[:]
            path2.append((r,c+1))
            todo.insert(0,(steps+1, r, c+1, 'E', path2))
    # check down
    if dir != 'N' and r < Y-1 and grid[r+1][c] in '.v':
        if (steps+1, r+1, c) not in cache:
            path2 = path[:]
            path2.append((r+1,c))
            todo.insert(0,(steps+1, r+1, c, 'S', path2))
    # check left
    if dir != 'E' and c > 0 and grid[r][c-1] in '.<':
        if (steps+1, r, c-1) not in cache:
            path2 = path[:]
            path2.append((r,c-1))
            todo.insert(0,(steps+1, r, c-1, 'W', path2))
    return todo


# main
lines = open('input_23.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

todo = [(0,r,c,'S',[(r,c)])] # this is the to do list
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
all_hikes = []
all_paths = []
i = 0
while len(todo) > 0: # and i < 1000:
    # break
    i += 1
    if i % 1 == 400000:
        print('i =',i,'todo[0] = ',todo[0])
    todo = move(todo)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))

# idx = all_hikes.index(max(all_hikes))
# path_grid = grid[:]
# for coords in all_paths[idx]:
#     path_grid[coords[0]][coords[1]] = 'O'
# print_grid(path_grid)
# Out:
# 141 141
# starting block = 0 1
# finished. r,c = 140 139 steps = 2230
# finished. r,c = 140 139 steps = 1846
# finished. r,c = 140 139 steps = 1834
# finished. r,c = 140 139 steps = 1726
# finished. r,c = 140 139 steps = 1774
# finished. r,c = 140 139 steps = 1922
# finished. r,c = 140 139 steps = 1910
# finished. r,c = 140 139 steps = 1898
# finished. r,c = 140 139 steps = 1790
# finished. r,c = 140 139 steps = 1838
# finished. r,c = 140 139 steps = 1986
# finished. r,c = 140 139 steps = 1646
# finished. r,c = 140 139 steps = 1538
# finished. r,c = 140 139 steps = 1586
# finished. r,c = 140 139 steps = 1734
# finished. r,c = 140 139 steps = 1666
# finished. r,c = 140 139 steps = 1814
# finished. r,c = 140 139 steps = 1954
# finished. r,c = 140 139 steps = 1778
# finished. r,c = 140 139 steps = 1670
# finished. r,c = 140 139 steps = 1718
# finished. r,c = 140 139 steps = 1866
# finished. r,c = 140 139 steps = 1526
# finished. r,c = 140 139 steps = 1418
# finished. r,c = 140 139 steps = 1466
# finished. r,c = 140 139 steps = 1614
# finished. r,c = 140 139 steps = 1606
# finished. r,c = 140 139 steps = 1654
# finished. r,c = 140 139 steps = 1802
# finished. r,c = 140 139 steps = 1546
# finished. r,c = 140 139 steps = 1694
# finished. r,c = 140 139 steps = 1590
# finished. r,c = 140 139 steps = 1482
# finished. r,c = 140 139 steps = 1530
# finished. r,c = 140 139 steps = 1678
# finished. r,c = 140 139 steps = 1610
# finished. r,c = 140 139 steps = 1758
# finished. r,c = 140 139 steps = 1818
# finished. r,c = 140 139 steps = 1958
# finished. r,c = 140 139 steps = 1950
# finished. r,c = 140 139 steps = 1682
# finished. r,c = 140 139 steps = 1574
# finished. r,c = 140 139 steps = 1622
# finished. r,c = 140 139 steps = 1770
# finished. r,c = 140 139 steps = 1430
# finished. r,c = 140 139 steps = 1322
# finished. r,c = 140 139 steps = 1370
# finished. r,c = 140 139 steps = 1518
# finished. r,c = 140 139 steps = 1510
# finished. r,c = 140 139 steps = 1558
# finished. r,c = 140 139 steps = 1706
# finished. r,c = 140 139 steps = 1450
# finished. r,c = 140 139 steps = 1598
# finished. r,c = 140 139 steps = 1738
# finished. r,c = 140 139 steps = 1494
# finished. r,c = 140 139 steps = 1386
# finished. r,c = 140 139 steps = 1434
# finished. r,c = 140 139 steps = 1582
# finished. r,c = 140 139 steps = 1514
# finished. r,c = 140 139 steps = 1662
# finished. r,c = 140 139 steps = 1630
# finished. r,c = 140 139 steps = 1826
# finished. r,c = 140 139 steps = 1570
# finished. r,c = 140 139 steps = 1858
# finished. r,c = 140 139 steps = 1722
# finished. r,c = 140 139 steps = 1862
# finished. r,c = 140 139 steps = 1854
# finished. r,c = 140 139 steps = 1522
# finished. r,c = 140 139 steps = 1414
# finished. r,c = 140 139 steps = 1462
# finished. r,c = 140 139 steps = 1602
# finished. r,c = 140 139 steps = 1650
# finished. r,c = 140 139 steps = 1798
# finished. r,c = 140 139 steps = 1542
# finished. r,c = 140 139 steps = 1690
# finished. r,c = 140 139 steps = 1830
# finished. r,c = 140 139 steps = 1658
# finished. r,c = 140 139 steps = 1746
# finished. r,c = 140 139 steps = 1886
# finished. r,c = 140 139 steps = 1750
# finished. r,c = 140 139 steps = 1890
# finished. r,c = 140 139 steps = 1882
# finished. r,c = 140 139 steps = 1562
# finished. r,c = 140 139 steps = 1710
# finished. r,c = 140 139 steps = 1850
# finished. r,c = 140 139 steps = 1566
# finished. r,c = 140 139 steps = 1714
# finished. r,c = 140 139 steps = 1874
# finished. r,c = 140 139 steps = 1766
# finished. r,c = 140 139 steps = 1962
# finished. r,c = 140 139 steps = 1702
# finished. r,c = 140 139 steps = 1642
# finished. r,c = 140 139 steps = 1930
# finished. r,c = 140 139 steps = 1686
# finished. r,c = 140 139 steps = 1578
# finished. r,c = 140 139 steps = 1626
# finished. r,c = 140 139 steps = 1994
# finished. r,c = 140 139 steps = 1822
# finished. r,c = 140 139 steps = 1870
# finished. r,c = 140 139 steps = 2018
# finished. r,c = 140 139 steps = 1762
# finished. r,c = 140 139 steps = 2050
# finished. r,c = 140 139 steps = 1914
# finished. r,c = 140 139 steps = 2054
# finished. r,c = 140 139 steps = 2046
# finished. r,c = 140 139 steps = 1794
# finished. r,c = 140 139 steps = 1842
# finished. r,c = 140 139 steps = 1990
# finished. r,c = 140 139 steps = 2022
# finished. r,c = 140 139 steps = 1938
# finished. r,c = 140 139 steps = 2078
# finished. r,c = 140 139 steps = 1942
# finished. r,c = 140 139 steps = 2082
# finished. r,c = 140 139 steps = 2074
# finished. r,c = 140 139 steps = 2010
# finished. r,c = 140 139 steps = 1754
# finished. r,c = 140 139 steps = 1902
# finished. r,c = 140 139 steps = 2042
# finished. r,c = 140 139 steps = 1906
# finished. r,c = 140 139 steps = 2038
# finished. r,c = 140 139 steps = 1918
# finished. r,c = 140 139 steps = 1618
# finished. r,c = 140 139 steps = 1806
# finished. r,c = 140 139 steps = 1698
# finished. r,c = 140 139 steps = 1974
# finished. r,c = 140 139 steps = 2006
# finished. r,c = 140 139 steps = 2002
# finished. r,c = 140 139 steps = 1878
# finished. r,c = 140 139 steps = 1934
# finished. r,c = 140 139 steps = 1982
# finished. r,c = 140 139 steps = 2130
# finished. r,c = 140 139 steps = 2162
# finished. r,c = 140 139 steps = 2026
# finished. r,c = 140 139 steps = 2166
# finished. r,c = 140 139 steps = 2158
# finished. r,c = 140 139 steps = 1894
# finished. r,c = 140 139 steps = 2034
# finished. r,c = 140 139 steps = 2142
# finished. r,c = 140 139 steps = 2282
# finished. r,c = 140 139 steps = 2274
# finished. r,c = 140 139 steps = 2286
# finished. r,c = 140 139 steps = 2406
# number of hikes = 142 longest hike = 2406

# %%
# part 2
def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]

def move(todo):
    steps, r, c, dir, path = todo.pop(0)
    # if we've been here before, end this thread
    # if (steps,r,c,dir) in cache:
    if (r,c,dir) in cache and steps+1 <= cache[(r,c,dir)]:
        # print(r,c,dir,'in cache')
        return todo
    else:
        cache[(r,c,dir)] = steps

    search_type = -1  # 0: depth-first search, -1: breadth-first search (shortest path)
    if r == X-1:
        if steps > 0*3000:
            print('finished. r,c =',r,c,'steps =',steps)
        all_hikes.append(steps)
        path.pop(0) # starting tile doesn't count
        all_paths.append(path)        
        return todo
    # check up
    if dir != 'S' and grid[r-1][c] in '.v^<>': # .v^<> 
        if (r-1,c) not in path:
            path2 = path[:]
            path2.append((r-1,c))
            todo.append((steps+1, r-1, c, 'N', path2))
    # check right
    if dir != 'W' and grid[r][c+1] in '.v^<>':
        if (r,c+1) not in path:
            path2 = path[:]
            path2.append((r,c+1))
            todo.append((steps+1, r, c+1, 'E', path2))
    # check down
    if dir != 'N' and grid[r+1][c] in '.v^<>':
        if (r+1,c) not in path:
            path2 = path[:]
            path2.append((r+1,c))
            todo.append((steps+1, r+1, c, 'S', path2))
    # check left
    if dir != 'E' and grid[r][c-1] in '.v^<>':
        if (r,c-1) not in path:
            path2 = path[:]
            path2.append((r,c-1))
            todo.append((steps+1, r, c-1, 'W', path2))
    return todo


# main
lines = open('input_23_test.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

todo = [(0,r,c,'S',[(r,c)])] # this is the to do list
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
all_hikes = []
all_paths = []
i = 0
while len(todo) > 0: # and i < 10000000:
    # break
    # i += 1
    # if i % 200000 == 0:
    #     print('i =',i,'todo[0] = ',todo[0][:-2])
    todo = move(todo)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))

idx = all_hikes.index(max(all_hikes))
path_grid = grid[:]
for coords in all_paths[idx]:
    path_grid[coords[0]][coords[1]] = 'O'

# print_grid(path_grid)
# 4942 is too low 49m 27.7s
# Out:
# 23 23
# starting block = 0 1
# finished. r,c = 22 21 steps = 74
# finished. r,c = 22 21 steps = 82
# finished. r,c = 22 21 steps = 82
# finished. r,c = 22 21 steps = 86
# finished. r,c = 22 21 steps = 90
# finished. r,c = 22 21 steps = 94
# finished. r,c = 22 21 steps = 110
# finished. r,c = 22 21 steps = 118
# finished. r,c = 22 21 steps = 118
# finished. r,c = 22 21 steps = 126
# finished. r,c = 22 21 steps = 150
# finished. r,c = 22 21 steps = 154
# number of hikes = 12 longest hike = 154

# %%
# print_grid(path_grid)
all_paths[idx]
# len(all_paths[idx])

# %%
# part 2 second try: keep track of only junctions, not full paths
def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]


def isnode(r,c):
    if r > 0 and  r < X-1: # and c > 0 and c < Y-1:
        neighbors = grid[r-1][c] + grid[r+1][c] + grid[r][c-1] + grid[r][c+1]
    else:
        return True
    return True if neighbors.count('#') < 2 else False


def move(todo,max_steps):
    steps, r, c, dir, path = todo.pop(0)
    # if (r,c,dir) in cache and steps == cache[(r,c,dir)]:  # way, way longer

    # if (steps,r,c,dir) in cache:  # this way worked
    #     return todo,max_steps
    # else:
    #     cache[(steps,r,c,dir)] = steps
    if r == X-1:
        all_hikes.append(steps)
        if steps > max_steps:
            max_steps = steps 
        # path.pop(0)
        all_paths.append(path)
        if steps > 0*2000:
            print('finished. r,c =',r,c,'steps =',steps,'current max steps = ',max_steps)
        return todo, max_steps
    
    search_type = 0  # 0: depth-first search, -1: breadth-first search (shortest path)
    path2 = path
    # check down
    if dir != 'N' and grid[r+1][c] in '.v^<>':
        if (r+1,c) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r+1,c):
                path2.append((r+1,c))
            todo.insert(search_type,(steps+1, r+1, c, 'S', path2))
            # todo.append((steps+1, r+1, c, 'S', path2))
    # check left
    if dir != 'E' and grid[r][c-1] in '.v^<>':
        if (r,c-1) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r,c-1):
                path2.append((r,c-1))
            todo.insert(search_type,(steps+1, r, c-1, 'W', path2))
            # todo.append((steps+1, r, c-1, 'W', path2))
    # check right
    if dir != 'W' and grid[r][c+1] in '.v^<>':
        if (r,c+1) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r,c+1):
                path2.append((r,c+1))
            todo.insert(search_type,(steps+1, r, c+1, 'E', path2))
            # todo.append((steps+1, r, c+1, 'E', path2))
    # check up
    if dir != 'S' and grid[r-1][c] in '.v^<>': # .v^<> 
        if (r-1,c) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r-1,c):
                path2.append((r-1,c))
            todo.insert(search_type,(steps+1, r-1, c, 'N', path2))
            # todo.append((steps+1, r-1, c, 'N', path2))
    return todo,max_steps


# main
lines = open('input_23_test.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

todo = [(0,r,c,'S',[(r,c)])] # this is the to do list
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
all_hikes = []
all_paths = []
max_steps = 0
i = 0
while len(todo) > 0 and i < 1000000:
    # break
    i += 1
    # if i % 100000 == 0:
    #     print('i =',i,'todo[0] = ',todo[0][:-2])
    #     print('length todo = ',len(todo),'toto[0] = ',todo[0])
    todo,max_steps = move(todo,max_steps)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))

idx = all_hikes.index(max(all_hikes))
# path_grid = grid[:]
# for coords in all_paths[idx]:
#     path_grid[coords[0]][coords[1]] = 'O'

# print_grid(path_grid)
# 4942 is too low 2m 8.5s
# number of hikes = 673 longest hike = 4762, 2m 40s BFS (append)
# number of hikes = 694 longest hike = 5398, 23s DFS (insert,0) search NESW
# number of hikes = 982 longest hike = 6026, 21s DFS (insert,0) search ESWN
# number of hikes = 966 longest hike = 6026, 21s DFS (insert,0) search EWNS
# number of hikes = 665 longest hike = 4730, 45s search EWNSE
# number of hikes = 1030 longest hike = 6218, 22s, search SEWN
# number of hikes = 1009 longest hike = 6218, 22s, search SWEN
# 6630 after 20 minutes but kept running for hours
# Out:
# 23 23
# starting block = 0 1
# finished. r,c = 22 21 steps = 150 current max steps =  150
# finished. r,c = 22 21 steps = 110 current max steps =  150
# finished. r,c = 22 21 steps = 82 current max steps =  150
# finished. r,c = 22 21 steps = 94 current max steps =  150
# finished. r,c = 22 21 steps = 126 current max steps =  150
# finished. r,c = 22 21 steps = 86 current max steps =  150
# finished. r,c = 22 21 steps = 118 current max steps =  150
# finished. r,c = 22 21 steps = 82 current max steps =  150
# finished. r,c = 22 21 steps = 74 current max steps =  150
# finished. r,c = 22 21 steps = 154 current max steps =  154
# finished. r,c = 22 21 steps = 118 current max steps =  154
# finished. r,c = 22 21 steps = 90 current max steps =  154
# number of hikes = 12 longest hike = 154

# %%
idx = all_hikes.index(max(all_hikes))
print(idx)
all_hikes[idx]
len(all_paths[idx])
# Out:
# 62
# 35

# %%
# part 2: next attempt: convert into grid with edge contraction

def backwards(dir):
    if dir == 0: return 2
    if dir == 1: return 3
    if dir == 2: return 0
    if dir == 3: return 1


def get_nextdir(r,c,dir):
    if r == X-1: return r,c, '#' 
    if dir == 0: return r-1, c, grid[r-1][c] # 'N'
    if dir == 1: return r, c+1, grid[r][c+1] # 'E'
    if dir == 2: return r+1, c, grid[r+1][c] # 'S'
    if dir == 3: return r, c-1, grid[r][c-1] # 'W'


def isnode(r,c):
    if r > 0 and  r < X-1: # and c > 0 and c < Y-1:
        neighbors = grid[r-1][c] + grid[r+1][c] + grid[r][c-1] + grid[r][c+1]
    else:
        return True
    return True if neighbors.count('#') < 2 else False


def move(todo):
    steps, r, c, dir = todo.pop(0)
    if (r,c) in cache:
        return todo
    else:
        cache[(r,c)] = steps

    acceptable_tiles = '.v^<>'
    if isnode(r,c):
        if (r,c) not in nodes:
            nodes[(r,c)] = steps
            for i in [2,3,1,0]:
                x,y,next_tile = get_nextdir(r,c, i)
                if next_tile in acceptable_tiles:
                    todo.append((1, x, y, i))
    else:
        nodes[(r,c)] = steps 
        # pick a path and walk to next node
        while not isnode(r,c):
            checkdirs = [2,1,3,0]  # look around all directions
            checkdirs.remove(backwards(dir))
            for i in checkdirs:
                x,y,next_tile = get_nextdir(r, c, i)
                if next_tile in acceptable_tiles:
                    i_move = i
            x,y,next_tile = get_nextdir(r, c, i_move)
            r,c,dir = x,y,i_move
            steps += 1
            # print(steps,r,c,dir)
        todo.append((0, r, c, steps))

                    
    # if r == X-1:
    #     all_hikes.append(steps)
    #     if steps > max_steps:
    #         max_steps = steps 
    #     # path.pop(0)
    #     # all_paths.append(path)
    #     if steps > 0*2000:
    #         print('finished. r,c =',r,c,'steps =',steps,'current max steps = ',max_steps)
    #     return todo, max_steps
    
    return todo


# main
lines = open('input_23_test.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

# direction: (N,E,S,W) = (0,1,2,3)
# todo = [(0,r,c,2,[(r,c)])] # this is the to do list: (steps, row, col, dir, path)
todo = [(0,r,c,2)] # this is the to do list: (steps, row, col, dir, path)
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
nodes = {}
all_hikes = []
all_paths = []
max_steps = 0
i = 0
while len(todo) > 0 and i < 1000000:
    # break
    i += 1
    if i % 1 == 0:
        print('i =',i,'todo[0] = ',todo[0][:-2])
        print('length todo = ',len(todo),'toto[0] = ',todo[0])
    todo = move(todo)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
# print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))
# Out:
# 23 23
# starting block = 0 1
# i = 1 todo[0] =  (0, 0)
# length todo =  1 toto[0] =  (0, 0, 1, 2)
# i = 2 todo[0] =  (1, 1)
# length todo =  1 toto[0] =  (1, 1, 1, 2)
# i = 3 todo[0] =  (0, 5)
# length todo =  1 toto[0] =  (0, 5, 3, 15)
# i = 4 todo[0] =  (1, 6)
# length todo =  3 toto[0] =  (1, 6, 3, 2)
# i = 5 todo[0] =  (1, 5)
# length todo =  3 toto[0] =  (1, 5, 4, 1)
# i = 6 todo[0] =  (1, 4)
# length todo =  3 toto[0] =  (1, 4, 3, 0)
# i = 7 todo[0] =  (0, 13)
# length todo =  3 toto[0] =  (0, 13, 5, 22)
# i = 8 todo[0] =  (0, 3)
# length todo =  5 toto[0] =  (0, 3, 11, 22)
# i = 9 todo[0] =  (0, 0)
# length todo =  7 toto[0] =  (0, 0, 1, 15)
# i = 10 todo[0] =  (1, 14)
# length todo =  6 toto[0] =  (1, 14, 5, 2)
# i = 11 todo[0] =  (1, 13)
# length todo =  6 toto[0] =  (1, 13, 6, 1)
# i = 12 todo[0] =  (1, 12)
# length todo =  6 toto[0] =  (1, 12, 5, 0)
# i = 13 todo[0] =  (1, 4)
# length todo =  6 toto[0] =  (1, 4, 11, 2)
# i = 14 todo[0] =  (1, 3)
# length todo =  6 toto[0] =  (1, 3, 10, 3)
# i = 15 todo[0] =  (1, 3)
# length todo =  6 toto[0] =  (1, 3, 12, 1)
# i = 16 todo[0] =  (0, 19)
# length todo =  6 toto[0] =  (0, 19, 13, 38)
# i = 17 todo[0] =  (0, 13)
# length todo =  8 toto[0] =  (0, 13, 13, 12)
# i = 18 todo[0] =  (0, 5)
# length todo =  11 toto[0] =  (0, 5, 3, 22)
# i = 19 todo[0] =  (0, 13)
# length todo =  10 toto[0] =  (0, 13, 13, 24)
# i = 20 todo[0] =  (0, 5)
# length todo =  9 toto[0] =  (0, 5, 3, 22)
# i = 21 todo[0] =  (0, 11)
# length todo =  8 toto[0] =  (0, 11, 21, 30)
# i = 22 todo[0] =  (1, 19)
# length todo =  10 toto[0] =  (1, 19, 12, 3)
# i = 23 todo[0] =  (1, 19)
# length todo =  10 toto[0] =  (1, 19, 14, 1)
# i = 24 todo[0] =  (1, 18)
# length todo =  10 toto[0] =  (1, 18, 13, 0)
# i = 25 todo[0] =  (1, 14)
# length todo =  10 toto[0] =  (1, 14, 13, 2)
# i = 26 todo[0] =  (1, 13)
# length todo =  10 toto[0] =  (1, 13, 12, 3)
# i = 27 todo[0] =  (1, 13)
# length todo =  10 toto[0] =  (1, 13, 14, 1)
# i = 28 todo[0] =  (1, 12)
# length todo =  10 toto[0] =  (1, 12, 13, 0)
# i = 29 todo[0] =  (1, 12)
# length todo =  10 toto[0] =  (1, 12, 21, 2)
# i = 30 todo[0] =  (1, 11)
# length todo =  10 toto[0] =  (1, 11, 20, 3)
# i = 31 todo[0] =  (1, 10)
# length todo =  10 toto[0] =  (1, 10, 21, 0)
# i = 32 todo[0] =  (0, 13)
# length todo =  10 toto[0] =  (0, 13, 5, 38)
# i = 33 todo[0] =  (0, 19)
# length todo =  9 toto[0] =  (0, 19, 19, 10)
# i = 34 todo[0] =  (0, 13)
# length todo =  11 toto[0] =  (0, 13, 13, 10)
# i = 35 todo[0] =  (0, 19)
# length todo =  10 toto[0] =  (0, 19, 13, 10)
# i = 36 todo[0] =  (0, 13)
# length todo =  9 toto[0] =  (0, 13, 5, 12)
# i = 37 todo[0] =  (0, 11)
# length todo =  8 toto[0] =  (0, 11, 21, 18)
# i = 38 todo[0] =  (0, 3)
# length todo =  7 toto[0] =  (0, 3, 11, 24)
# i = 39 todo[0] =  (0, 19)
# length todo =  6 toto[0] =  (0, 19, 19, 10)
# i = 40 todo[0] =  (0, 13)
# length todo =  5 toto[0] =  (0, 13, 13, 18)
# i = 41 todo[0] =  (0, 3)
# length todo =  4 toto[0] =  (0, 3, 11, 30)
# i = 42 todo[0] =  (1, 20)
# length todo =  3 toto[0] =  (1, 20, 19, 2)
# i = 43 todo[0] =  (1, 19)
# length todo =  3 toto[0] =  (1, 19, 18, 3)
# i = 44 todo[0] =  (1, 18)
# length todo =  3 toto[0] =  (1, 18, 19, 0)
# i = 45 todo[0] =  (0, 22)
# length todo =  3 toto[0] =  (0, 22, 21, 5)
# i = 46 todo[0] =  (0, 19)
# length todo =  2 toto[0] =  (0, 19, 13, 10)
# i = 47 todo[0] =  (0, 11)
# length todo =  1 toto[0] =  (0, 11, 21, 10)

# %%
print(len(nodes))
print(len(cache))
# 141*141/2
# node_grid = grid[:]
# for coords in nodes:
#     node_grid[coords[0]][coords[1]] = 'O'
print_grid(grid)
[print(x) for x in nodes]
print(nodes)
A = [1,2,3,4]
print(A)
A.remove(3)
A
# Out:
# 32
# 32
# #.#####################
# #.......#########...###
# #######.#########.#.###
# ###.....#.>.>.###.#.###
# ###v#####.#v#.###.#.###
# ###.>...#.#.#.....#...#
# ###v###.#.#.#########.#
# ###...#.#.#.......#...#
# #####.#.#.#######.#.###
# #.....#.#.#.......#...#
# #.#####.#.#.#########v#
# #.#...#...#...###...>.#
# #.#.#v#######v###.###v#
# #...#.>.#...>.>.#.###.#
# #####v#.#.###v#.#.###.#
# #.....#...#...#.#.#...#
# #.#########.###.#.#.###
# #...###...#...#...#.###
# ###.###.#.###v#####v###
# #...#...#.#.>.>.#.>.###
# #.###.###.#.###.#.#v###
# #.....###...###...#...#
# #####################.#
# (0, 1)
# (1, 1)
# (5, 3)
# (6, 3)
# (5, 4)
# (4, 3)
# (13, 5)
# (3, 11)
# (14, 5)
# (13, 6)
# (12, 5)
# (4, 11)
# (3, 10)
# (3, 12)
# (19, 13)
# (13, 13)
# (11, 21)
# (19, 12)
# (19, 14)
# (18, 13)
# (14, 13)
# (13, 12)
# (13, 14)
# (12, 13)
# (12, 21)
# (11, 20)
# (10, 21)
# (19, 19)
# (20, 19)
# (19, 18)
# (18, 19)
# (22, 21)
# {(0, 1): 0, (1, 1): 1, (5, 3): 0, (6, 3): 1, (5, 4): 1, (4, 3): 1, (13, 5): 0, (3, 11): 0, (14, 5): 1, (13, 6): 1, (12, 5): 1, (4, 11): 1, (3, 10): 1, (3, 12): 1, (19, 13): 0, (13, 13): 0, (11, 21): 0, (19, 12): 1, (19, 14): 1, (18, 13): 1, (14, 13): 1, (13, 12): 1, (13, 14): 1, (12, 13): 1, (12, 21): 1, (11, 20): 1, (10, 21): 1, (19, 19): 0, (20, 19): 1, (19, 18): 1, (18, 19): 1, (22, 21): 0}
# [1, 2, 3, 4]
# [1, 2, 4]
