# %%
# part 1
def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]


def move(todo):
    steps, r, c, dir, path = todo.pop(0)
    # print(steps,r,c)
    # if we've been here before, end this thread
    if (steps,r,c,dir) in cache:
        # print(r,c,dir,'in cache')
        return todo
    else:
        # add this state to the cache
        # cache[state] = 0
        cache[(steps,r,c,dir)] = 0

    if r == X-1:
        print('finished. r,c =',r,c,'steps =',steps)
        all_hikes.append(steps)
        path.pop(0)
        all_paths.append(path)        
        return todo
    # check up
    if dir != 'S' and r > 0 and grid[r-1][c] in '.^':
        if (steps+1, r-1, c) not in cache:
            path2 = path[:]
            path2.append((r-1,c))
            todo.insert(0,(steps+1, r-1, c, 'N', path2))
    # check right
    if dir != 'W' and c < X-1 and grid[r][c+1] in '.>':
        if (steps+1, r, c+1) not in cache:
            path2 = path[:]
            path2.append((r,c+1))
            todo.insert(0,(steps+1, r, c+1, 'E', path2))
    # check down
    if dir != 'N' and r < Y-1 and grid[r+1][c] in '.v':
        if (steps+1, r+1, c) not in cache:
            path2 = path[:]
            path2.append((r+1,c))
            todo.insert(0,(steps+1, r+1, c, 'S', path2))
    # check left
    if dir != 'E' and c > 0 and grid[r][c-1] in '.<':
        if (steps+1, r, c-1) not in cache:
            path2 = path[:]
            path2.append((r,c-1))
            todo.insert(0,(steps+1, r, c-1, 'W', path2))
    return todo


# main
lines = open('input_23.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

todo = [(0,r,c,'S',[(r,c)])] # this is the to do list
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
all_hikes = []
all_paths = []
i = 0
while len(todo) > 0: # and i < 1000:
    # break
    i += 1
    if i % 1 == 400000:
        print('i =',i,'todo[0] = ',todo[0])
    todo = move(todo)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))

# idx = all_hikes.index(max(all_hikes))
# path_grid = grid[:]
# for coords in all_paths[idx]:
#     path_grid[coords[0]][coords[1]] = 'O'
# print_grid(path_grid)
# Out:
# 141 141
# starting block = 0 1
# finished. r,c = 140 139 steps = 2230
# finished. r,c = 140 139 steps = 1846
# finished. r,c = 140 139 steps = 1834
# finished. r,c = 140 139 steps = 1726
# finished. r,c = 140 139 steps = 1774
# finished. r,c = 140 139 steps = 1922
# finished. r,c = 140 139 steps = 1910
# finished. r,c = 140 139 steps = 1898
# finished. r,c = 140 139 steps = 1790
# finished. r,c = 140 139 steps = 1838
# finished. r,c = 140 139 steps = 1986
# finished. r,c = 140 139 steps = 1646
# finished. r,c = 140 139 steps = 1538
# finished. r,c = 140 139 steps = 1586
# finished. r,c = 140 139 steps = 1734
# finished. r,c = 140 139 steps = 1666
# finished. r,c = 140 139 steps = 1814
# finished. r,c = 140 139 steps = 1954
# finished. r,c = 140 139 steps = 1778
# finished. r,c = 140 139 steps = 1670
# finished. r,c = 140 139 steps = 1718
# finished. r,c = 140 139 steps = 1866
# finished. r,c = 140 139 steps = 1526
# finished. r,c = 140 139 steps = 1418
# finished. r,c = 140 139 steps = 1466
# finished. r,c = 140 139 steps = 1614
# finished. r,c = 140 139 steps = 1606
# finished. r,c = 140 139 steps = 1654
# finished. r,c = 140 139 steps = 1802
# finished. r,c = 140 139 steps = 1546
# finished. r,c = 140 139 steps = 1694
# finished. r,c = 140 139 steps = 1590
# finished. r,c = 140 139 steps = 1482
# finished. r,c = 140 139 steps = 1530
# finished. r,c = 140 139 steps = 1678
# finished. r,c = 140 139 steps = 1610
# finished. r,c = 140 139 steps = 1758
# finished. r,c = 140 139 steps = 1818
# finished. r,c = 140 139 steps = 1958
# finished. r,c = 140 139 steps = 1950
# finished. r,c = 140 139 steps = 1682
# finished. r,c = 140 139 steps = 1574
# finished. r,c = 140 139 steps = 1622
# finished. r,c = 140 139 steps = 1770
# finished. r,c = 140 139 steps = 1430
# finished. r,c = 140 139 steps = 1322
# finished. r,c = 140 139 steps = 1370
# finished. r,c = 140 139 steps = 1518
# finished. r,c = 140 139 steps = 1510
# finished. r,c = 140 139 steps = 1558
# finished. r,c = 140 139 steps = 1706
# finished. r,c = 140 139 steps = 1450
# finished. r,c = 140 139 steps = 1598
# finished. r,c = 140 139 steps = 1738
# finished. r,c = 140 139 steps = 1494
# finished. r,c = 140 139 steps = 1386
# finished. r,c = 140 139 steps = 1434
# finished. r,c = 140 139 steps = 1582
# finished. r,c = 140 139 steps = 1514
# finished. r,c = 140 139 steps = 1662
# finished. r,c = 140 139 steps = 1630
# finished. r,c = 140 139 steps = 1826
# finished. r,c = 140 139 steps = 1570
# finished. r,c = 140 139 steps = 1858
# finished. r,c = 140 139 steps = 1722
# finished. r,c = 140 139 steps = 1862
# finished. r,c = 140 139 steps = 1854
# finished. r,c = 140 139 steps = 1522
# finished. r,c = 140 139 steps = 1414
# finished. r,c = 140 139 steps = 1462
# finished. r,c = 140 139 steps = 1602
# finished. r,c = 140 139 steps = 1650
# finished. r,c = 140 139 steps = 1798
# finished. r,c = 140 139 steps = 1542
# finished. r,c = 140 139 steps = 1690
# finished. r,c = 140 139 steps = 1830
# finished. r,c = 140 139 steps = 1658
# finished. r,c = 140 139 steps = 1746
# finished. r,c = 140 139 steps = 1886
# finished. r,c = 140 139 steps = 1750
# finished. r,c = 140 139 steps = 1890
# finished. r,c = 140 139 steps = 1882
# finished. r,c = 140 139 steps = 1562
# finished. r,c = 140 139 steps = 1710
# finished. r,c = 140 139 steps = 1850
# finished. r,c = 140 139 steps = 1566
# finished. r,c = 140 139 steps = 1714
# finished. r,c = 140 139 steps = 1874
# finished. r,c = 140 139 steps = 1766
# finished. r,c = 140 139 steps = 1962
# finished. r,c = 140 139 steps = 1702
# finished. r,c = 140 139 steps = 1642
# finished. r,c = 140 139 steps = 1930
# finished. r,c = 140 139 steps = 1686
# finished. r,c = 140 139 steps = 1578
# finished. r,c = 140 139 steps = 1626
# finished. r,c = 140 139 steps = 1994
# finished. r,c = 140 139 steps = 1822
# finished. r,c = 140 139 steps = 1870
# finished. r,c = 140 139 steps = 2018
# finished. r,c = 140 139 steps = 1762
# finished. r,c = 140 139 steps = 2050
# finished. r,c = 140 139 steps = 1914
# finished. r,c = 140 139 steps = 2054
# finished. r,c = 140 139 steps = 2046
# finished. r,c = 140 139 steps = 1794
# finished. r,c = 140 139 steps = 1842
# finished. r,c = 140 139 steps = 1990
# finished. r,c = 140 139 steps = 2022
# finished. r,c = 140 139 steps = 1938
# finished. r,c = 140 139 steps = 2078
# finished. r,c = 140 139 steps = 1942
# finished. r,c = 140 139 steps = 2082
# finished. r,c = 140 139 steps = 2074
# finished. r,c = 140 139 steps = 2010
# finished. r,c = 140 139 steps = 1754
# finished. r,c = 140 139 steps = 1902
# finished. r,c = 140 139 steps = 2042
# finished. r,c = 140 139 steps = 1906
# finished. r,c = 140 139 steps = 2038
# finished. r,c = 140 139 steps = 1918
# finished. r,c = 140 139 steps = 1618
# finished. r,c = 140 139 steps = 1806
# finished. r,c = 140 139 steps = 1698
# finished. r,c = 140 139 steps = 1974
# finished. r,c = 140 139 steps = 2006
# finished. r,c = 140 139 steps = 2002
# finished. r,c = 140 139 steps = 1878
# finished. r,c = 140 139 steps = 1934
# finished. r,c = 140 139 steps = 1982
# finished. r,c = 140 139 steps = 2130
# finished. r,c = 140 139 steps = 2162
# finished. r,c = 140 139 steps = 2026
# finished. r,c = 140 139 steps = 2166
# finished. r,c = 140 139 steps = 2158
# finished. r,c = 140 139 steps = 1894
# finished. r,c = 140 139 steps = 2034
# finished. r,c = 140 139 steps = 2142
# finished. r,c = 140 139 steps = 2282
# finished. r,c = 140 139 steps = 2274
# finished. r,c = 140 139 steps = 2286
# finished. r,c = 140 139 steps = 2406
# number of hikes = 142 longest hike = 2406

# %%
# part 2
def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]

def move(todo):
    steps, r, c, dir, path = todo.pop(0)
    # if we've been here before, end this thread
    # if (steps,r,c,dir) in cache:
    if (r,c,dir) in cache and steps+1 <= cache[(r,c,dir)]:
        # print(r,c,dir,'in cache')
        return todo
    else:
        cache[(r,c,dir)] = steps

    search_type = -1  # 0: depth-first search, -1: breadth-first search (shortest path)
    if r == X-1:
        if steps > 0*3000:
            print('finished. r,c =',r,c,'steps =',steps)
        all_hikes.append(steps)
        path.pop(0) # starting tile doesn't count
        all_paths.append(path)        
        return todo
    # check up
    if dir != 'S' and grid[r-1][c] in '.v^<>': # .v^<> 
        if (r-1,c) not in path:
            path2 = path[:]
            path2.append((r-1,c))
            todo.append((steps+1, r-1, c, 'N', path2))
    # check right
    if dir != 'W' and grid[r][c+1] in '.v^<>':
        if (r,c+1) not in path:
            path2 = path[:]
            path2.append((r,c+1))
            todo.append((steps+1, r, c+1, 'E', path2))
    # check down
    if dir != 'N' and grid[r+1][c] in '.v^<>':
        if (r+1,c) not in path:
            path2 = path[:]
            path2.append((r+1,c))
            todo.append((steps+1, r+1, c, 'S', path2))
    # check left
    if dir != 'E' and grid[r][c-1] in '.v^<>':
        if (r,c-1) not in path:
            path2 = path[:]
            path2.append((r,c-1))
            todo.append((steps+1, r, c-1, 'W', path2))
    return todo


# main
lines = open('input_23_test.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

todo = [(0,r,c,'S',[(r,c)])] # this is the to do list
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
all_hikes = []
all_paths = []
i = 0
while len(todo) > 0: # and i < 10000000:
    # break
    # i += 1
    # if i % 200000 == 0:
    #     print('i =',i,'todo[0] = ',todo[0][:-2])
    todo = move(todo)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))

idx = all_hikes.index(max(all_hikes))
path_grid = grid[:]
for coords in all_paths[idx]:
    path_grid[coords[0]][coords[1]] = 'O'

# print_grid(path_grid)
# 4942 is too low 49m 27.7s
# Out:
# 23 23
# starting block = 0 1
# finished. r,c = 22 21 steps = 74
# finished. r,c = 22 21 steps = 82
# finished. r,c = 22 21 steps = 82
# finished. r,c = 22 21 steps = 86
# finished. r,c = 22 21 steps = 90
# finished. r,c = 22 21 steps = 94
# finished. r,c = 22 21 steps = 110
# finished. r,c = 22 21 steps = 118
# finished. r,c = 22 21 steps = 118
# finished. r,c = 22 21 steps = 126
# finished. r,c = 22 21 steps = 150
# finished. r,c = 22 21 steps = 154
# number of hikes = 12 longest hike = 154

# %%
# print_grid(path_grid)
all_paths[idx]
# len(all_paths[idx])

# %%
# part 2 second try: keep track of only junctions, not full paths
def print_grid(G):
    temp = [''.join(x) for x in G]
    [print(x) for x in temp]


def isnode(r,c):
    if r > 0 and  r < X-1: # and c > 0 and c < Y-1:
        neighbors = grid[r-1][c] + grid[r+1][c] + grid[r][c-1] + grid[r][c+1]
    else:
        return True
    return True if neighbors.count('#') < 2 else False


def move(todo,max_steps):
    steps, r, c, dir, path = todo.pop(0)
    # if (r,c,dir) in cache and steps == cache[(r,c,dir)]:  # way, way longer

    # if (steps,r,c,dir) in cache:  # this way worked
    #     return todo,max_steps
    # else:
    #     cache[(steps,r,c,dir)] = steps
    if r == X-1:
        all_hikes.append(steps)
        if steps > max_steps:
            max_steps = steps 
        # path.pop(0)
        all_paths.append(path)
        if steps > 0*2000:
            print('finished. r,c =',r,c,'steps =',steps,'current max steps = ',max_steps)
        return todo, max_steps
    
    search_type = 0  # 0: depth-first search, -1: breadth-first search (shortest path)
    path2 = path
    # check down
    if dir != 'N' and grid[r+1][c] in '.v^<>':
        if (r+1,c) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r+1,c):
                path2.append((r+1,c))
            todo.insert(search_type,(steps+1, r+1, c, 'S', path2))
            # todo.append((steps+1, r+1, c, 'S', path2))
    # check left
    if dir != 'E' and grid[r][c-1] in '.v^<>':
        if (r,c-1) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r,c-1):
                path2.append((r,c-1))
            todo.insert(search_type,(steps+1, r, c-1, 'W', path2))
            # todo.append((steps+1, r, c-1, 'W', path2))
    # check right
    if dir != 'W' and grid[r][c+1] in '.v^<>':
        if (r,c+1) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r,c+1):
                path2.append((r,c+1))
            todo.insert(search_type,(steps+1, r, c+1, 'E', path2))
            # todo.append((steps+1, r, c+1, 'E', path2))
    # check up
    if dir != 'S' and grid[r-1][c] in '.v^<>': # .v^<> 
        if (r-1,c) not in path:
            # path2 = path
            path2 = path[:]
            if isnode(r-1,c):
                path2.append((r-1,c))
            todo.insert(search_type,(steps+1, r-1, c, 'N', path2))
            # todo.append((steps+1, r-1, c, 'N', path2))
    return todo,max_steps


# main
lines = open('input_23_test.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
startcol = lines[0].find('.')
r,c = (0,startcol)
print('starting block =',r,c)

todo = [(0,r,c,'S',[(r,c)])] # this is the to do list
cache = {}   # list of all places been: (row, col, dir, total steps, value = path list)
all_hikes = []
all_paths = []
max_steps = 0
i = 0
while len(todo) > 0 and i < 1000000:
    # break
    i += 1
    # if i % 100000 == 0:
    #     print('i =',i,'todo[0] = ',todo[0][:-2])
    #     print('length todo = ',len(todo),'toto[0] = ',todo[0])
    todo,max_steps = move(todo,max_steps)
    # print_cache(cache_grid)
# print_cache(cache_grid)
# print(cache.keys())
print('number of hikes =',len(all_hikes),'longest hike =',max(all_hikes))

idx = all_hikes.index(max(all_hikes))
# path_grid = grid[:]
# for coords in all_paths[idx]:
#     path_grid[coords[0]][coords[1]] = 'O'

# print_grid(path_grid)
# 4942 is too low 2m 8.5s
# number of hikes = 673 longest hike = 4762, 2m 40s BFS (append)
# number of hikes = 694 longest hike = 5398, 23s DFS (insert,0) search NESW
# number of hikes = 982 longest hike = 6026, 21s DFS (insert,0) search ESWN
# number of hikes = 966 longest hike = 6026, 21s DFS (insert,0) search EWNS
# number of hikes = 665 longest hike = 4730, 45s search EWNSE
# number of hikes = 1030 longest hike = 6218, 22s, search SEWN
# number of hikes = 1009 longest hike = 6218, 22s, search SWEN
# 6630 after 20 minutes but kept running for hours
# Out:
# 23 23
# starting block = 0 1
# finished. r,c = 22 21 steps = 150 current max steps =  150
# finished. r,c = 22 21 steps = 110 current max steps =  150
# finished. r,c = 22 21 steps = 82 current max steps =  150
# finished. r,c = 22 21 steps = 94 current max steps =  150
# finished. r,c = 22 21 steps = 126 current max steps =  150
# finished. r,c = 22 21 steps = 86 current max steps =  150
# finished. r,c = 22 21 steps = 118 current max steps =  150
# finished. r,c = 22 21 steps = 82 current max steps =  150
# finished. r,c = 22 21 steps = 74 current max steps =  150
# finished. r,c = 22 21 steps = 154 current max steps =  154
# finished. r,c = 22 21 steps = 118 current max steps =  154
# finished. r,c = 22 21 steps = 90 current max steps =  154
# number of hikes = 12 longest hike = 154

# %%
# part 2: next attempt: convert into grid with edge contraction

def backwards(dir):
    return {0:2, 1:3, 2:0, 3:1}.get(dir)


def get_nextdir(r,c,dir):
    if r == X-1: return r,c, '#' 
    if dir == 0: return r-1, c, grid[r-1][c] # 'N'
    if dir == 1: return r, c+1, grid[r][c+1] # 'E'
    if dir == 2: return r+1, c, grid[r+1][c] # 'S'
    if dir == 3: return r, c-1, grid[r][c-1] # 'W'


def isnode(r,c):
    if r > 0 and  r < X-1: # and c > 0 and c < Y-1:
        neighbors = grid[r-1][c] + grid[r+1][c] + grid[r][c-1] + grid[r][c+1]
    else:
        return True
    return True if neighbors.count('#') < 2 else False


def move(todo):
    steps, r, c, dir, start_node = todo.pop(0)

    acceptable_tiles = '.v^<>'
    if isnode(r,c):
        if (r,c) not in nodes:
            if steps > 1:
                nodes[(r,c)] = {start_node: steps}
                nodes[start_node] = {(r,c): steps}
                # print(f'add node: {r,c}, start_node = {start_node}, steps = {steps}')
            for i in [2,3,1,0]:
                x,y,next_tile = get_nextdir(r,c, i)
                if next_tile in acceptable_tiles:
                    todo.append((1, x, y, i, (r,c)))
        else:
            # if (start_node, steps) not in nodes[(r,c)]:
            nodes[(r,c)][start_node] = steps
            nodes[start_node][(r,c)]  = steps
    else:
        # pick a path and walk to next node
        while not isnode(r,c):
            checkdirs = [2,1,3,0]  # look around all directions
            checkdirs.remove(backwards(dir))
            for i in checkdirs:
                x,y,next_tile = get_nextdir(r, c, i)
                if next_tile in acceptable_tiles:
                    i_move = i
            x,y,next_tile = get_nextdir(r, c, i_move)
            r,c,dir = x,y,i_move
            steps += 1
            # print(steps,r,c,dir)
        todo.append((steps, r, c, -1, start_node))
    return todo


# main
lines = open('input_23.txt').read().splitlines()
# [print(x) for x in lines]
grid = [list(x) for x in lines]
print(len(grid), len(grid[0]))

X = len(grid)
Y = len(grid[0])
# cache_grid = [['.']*X for x in range(Y)]
# print_cache(cache_grid)

# find start location
start_node = (0,lines[0].find('.'))
end_node = (X-1,lines[X-1].find('.'))
print(f'starting tile = {start_node}. Ending tile = {end_node}')
r,c = start_node
todo = [(0,r,c,2,(r,c))] # this is the to do list: (steps, row, col, dir, path)
nodes = {}
max_steps = 0
i = 0
while len(todo) > 0 and i < 1000000:
    # break
    i += 1
    # if i % 1 == 0:
    #     print('i =',i,'todo[0] = ',todo[0][:-2])
    #     print('length todo = ',len(todo),'toto[0] = ',todo[0])
    todo = move(todo)
    # print_cache(cache_grid)
print('len nodes =',len(nodes))
print(nodes)
print(' ')
[print(f'{x} : {nodes[x]}') for x in nodes]
# Out:
# 141 141
# starting tile = (0, 1). Ending tile = (140, 139)
# len nodes = 36
# {(13, 11): {(19, 43): 290, (0, 1): 155, (33, 15): 116}, (0, 1): {(13, 11): 155}, (33, 15): {(33, 31): 64, (13, 11): 116, (67, 13): 316}, (19, 43): {(17, 59): 134, (33, 31): 82}, (67, 13): {(65, 29): 62, (33, 15): 316, (81, 7): 88}, (33, 31): {(29, 61): 146, (19, 43): 82, (65, 29): 218}, (17, 59): {(13, 83): 236, (29, 61): 58}, (81, 7): {(79, 43): 186, (67, 13): 88, (107, 19): 206}, (65, 29): {(63, 53): 122, (33, 31): 218, (79, 43): 92}, (29, 61): {(35, 89): 142, (17, 59): 58, (63, 53): 222}, (13, 83): {(5, 113): 278, (35, 89): 120}, (107, 19): {(101, 29): 72, (81, 7): 206, (123, 43): 576}, (79, 43): {(77, 53): 24, (65, 29): 92, (101, 29): 156}, (63, 53): {(53, 75): 120, (29, 61): 222, (77, 53): 58}, (35, 89): {(37, 113): 118, (13, 83): 120, (53, 75): 164}, (5, 113): {(43, 129): 434, (37, 113): 208}, (123, 43): {(125, 65): 256, (101, 29): 120}, (101, 29): {(101, 63): 218, (79, 43): 156}, (77, 53): {(85, 87): 162, (63, 53): 58, (101, 63): 98}, (53, 75): {(61, 109): 238, (35, 89): 164, (85, 87): 156}, (37, 113): {(35, 89): 118, (5, 113): 208, (61, 109): 152, (43, 129): 106}, (43, 129): {(67, 131): 162, (37, 113): 106, (5, 113): 434}, (125, 65): {(127, 77): 94, (101, 63): 146}, (101, 63): {(105, 81): 38, (77, 53): 98}, (85, 87): {(79, 103): 126, (53, 75): 156, (105, 81): 162}, (61, 109): {(53, 75): 238, (37, 113): 152, (79, 103): 48, (67, 131): 104}, (67, 131): {(79, 131): 76, (61, 109): 104, (43, 129): 162}, (127, 77): {(137, 105): 206, (105, 81): 94}, (105, 81): {(105, 109): 204, (85, 87): 162}, (79, 103): {(85, 87): 126, (61, 109): 48, (105, 109): 132, (79, 131): 140}, (79, 131): {(101, 125): 188, (79, 103): 140, (67, 131): 76}, (137, 105): {(129, 123): 82, (105, 109): 144}, (105, 109): {(105, 81): 204, (79, 103): 132, (137, 105): 144, (101, 125): 56}, (101, 125): {(79, 131): 188, (105, 109): 56, (129, 123): 318}, (129, 123): {(140, 139): 135, (137, 105): 82, (101, 125): 318}, (140, 139): {(129, 123): 135}}
#
# (13, 11) : {(19, 43): 290, (0, 1): 155, (33, 15): 116}
# (0, 1) : {(13, 11): 155}
# (33, 15) : {(33, 31): 64, (13, 11): 116, (67, 13): 316}
# (19, 43) : {(17, 59): 134, (33, 31): 82}
# (67, 13) : {(65, 29): 62, (33, 15): 316, (81, 7): 88}
# (33, 31) : {(29, 61): 146, (19, 43): 82, (65, 29): 218}
# (17, 59) : {(13, 83): 236, (29, 61): 58}
# (81, 7) : {(79, 43): 186, (67, 13): 88, (107, 19): 206}
# (65, 29) : {(63, 53): 122, (33, 31): 218, (79, 43): 92}
# (29, 61) : {(35, 89): 142, (17, 59): 58, (63, 53): 222}
# (13, 83) : {(5, 113): 278, (35, 89): 120}
# (107, 19) : {(101, 29): 72, (81, 7): 206, (123, 43): 576}
# (79, 43) : {(77, 53): 24, (65, 29): 92, (101, 29): 156}
# (63, 53) : {(53, 75): 120, (29, 61): 222, (77, 53): 58}
# (35, 89) : {(37, 113): 118, (13, 83): 120, (53, 75): 164}
# (5, 113) : {(43, 129): 434, (37, 113): 208}
# (123, 43) : {(125, 65): 256, (101, 29): 120}
# (101, 29) : {(101, 63): 218, (79, 43): 156}
# (77, 53) : {(85, 87): 162, (63, 53): 58, (101, 63): 98}
# (53, 75) : {(61, 109): 238, (35, 89): 164, (85, 87): 156}
# (37, 113) : {(35, 89): 118, (5, 113): 208, (61, 109): 152, (43, 129): 106}
# (43, 129) : {(67, 131): 162, (37, 113): 106, (5, 113): 434}
# (125, 65) : {(127, 77): 94, (101, 63): 146}
# (101, 63) : {(105, 81): 38, (77, 53): 98}
# (85, 87) : {(79, 103): 126, (53, 75): 156, (105, 81): 162}
# (61, 109) : {(53, 75): 238, (37, 113): 152, (79, 103): 48, (67, 131): 104}
# (67, 131) : {(79, 131): 76, (61, 109): 104, (43, 129): 162}
# (127, 77) : {(137, 105): 206, (105, 81): 94}
# (105, 81) : {(105, 109): 204, (85, 87): 162}
# (79, 103) : {(85, 87): 126, (61, 109): 48, (105, 109): 132, (79, 131): 140}
# (79, 131) : {(101, 125): 188, (79, 103): 140, (67, 131): 76}
# (137, 105) : {(129, 123): 82, (105, 109): 144}
# (105, 109) : {(105, 81): 204, (79, 103): 132, (137, 105): 144, (101, 125): 56}
# (101, 125) : {(79, 131): 188, (105, 109): 56, (129, 123): 318}
# (129, 123) : {(140, 139): 135, (137, 105): 82, (101, 125): 318}
# (140, 139) : {(129, 123): 135}
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# part 2, now do a search for all paths thru the nodes
from heapq import heappop, heappush

def hop(todo:list, end_node, max_steps):
    steps, path = todo.pop()
    # print(steps, path)
    if path[-1] == end_node:
        if steps > max_steps:
            max_steps = steps 
        print(f'finished. steps = {steps}. Current max Steps = {max_steps}')
        return todo, max_steps

    for neighbor, edge in nodes[path[-1]].items():
        # print(neighbor, edge)
        if neighbor not in path:
            path2 = path[:]
            path2.append(neighbor)
            todo.insert(0,(steps + edge, path2))
    return todo, max_steps

# main
# nodes = {'A':[('B',2),('C',1)], 
#         'B':[('A',2),('F',2),('C',3)],
#         'C':[('A',1),('B',3),('F',4)],
#         'F':[('B',2),('C',4)]}
# start = 'A'
# end_node = 'F'
# todo = [(0,'A')]
# seen = set()
path = [(start_node)]
todo = [(0,path)]
max_steps = 0
i = 0
while len(todo) > 0 and i < 10000:
    # print(todo)
    todo, max_steps = hop(todo, end_node, max_steps)
print(f'Done. Max Steps = {max_steps}')
# Out:
# finished. steps = 2406. Current max Steps = 2406
# finished. steps = 2230. Current max Steps = 2406
# finished. steps = 1994. Current max Steps = 2406
# finished. steps = 2142. Current max Steps = 2406
# finished. steps = 2282. Current max Steps = 2406
# finished. steps = 2274. Current max Steps = 2406
# finished. steps = 2286. Current max Steps = 2406
# finished. steps = 1746. Current max Steps = 2406
# finished. steps = 1894. Current max Steps = 2406
# finished. steps = 2034. Current max Steps = 2406
# finished. steps = 2026. Current max Steps = 2406
# finished. steps = 2038. Current max Steps = 2406
# finished. steps = 1878. Current max Steps = 2406
# finished. steps = 2026. Current max Steps = 2406
# finished. steps = 2166. Current max Steps = 2406
# finished. steps = 2158. Current max Steps = 2406
# finished. steps = 1874. Current max Steps = 2406
# finished. steps = 2022. Current max Steps = 2406
# finished. steps = 2162. Current max Steps = 2406
# finished. steps = 1982. Current max Steps = 2406
# finished. steps = 2130. Current max Steps = 2406
# finished. steps = 1590. Current max Steps = 2406
# finished. steps = 1738. Current max Steps = 2406
# finished. steps = 1878. Current max Steps = 2406
# finished. steps = 1870. Current max Steps = 2406
# finished. steps = 1882. Current max Steps = 2406
# finished. steps = 1722. Current max Steps = 2406
# finished. steps = 1870. Current max Steps = 2406
# finished. steps = 2010. Current max Steps = 2406
# finished. steps = 2002. Current max Steps = 2406
# finished. steps = 1718. Current max Steps = 2406
# finished. steps = 1866. Current max Steps = 2406
# finished. steps = 2006. Current max Steps = 2406
# finished. steps = 1826. Current max Steps = 2406
# finished. steps = 1974. Current max Steps = 2406
# finished. steps = 1758. Current max Steps = 2406
# finished. steps = 1906. Current max Steps = 2406
# finished. steps = 2046. Current max Steps = 2406
# finished. steps = 2038. Current max Steps = 2406
# finished. steps = 1754. Current max Steps = 2406
# finished. steps = 1902. Current max Steps = 2406
# finished. steps = 2042. Current max Steps = 2406
# finished. steps = 1862. Current max Steps = 2406
# finished. steps = 2010. Current max Steps = 2406
# finished. steps = 1698. Current max Steps = 2406
# finished. steps = 1846. Current max Steps = 2406
# finished. steps = 1986. Current max Steps = 2406
# finished. steps = 1806. Current max Steps = 2406
# finished. steps = 1954. Current max Steps = 2406
# finished. steps = 1618. Current max Steps = 2406
# finished. steps = 1766. Current max Steps = 2406
# finished. steps = 1626. Current max Steps = 2406
# finished. steps = 1774. Current max Steps = 2406
# finished. steps = 1914. Current max Steps = 2406
# finished. steps = 1906. Current max Steps = 2406
# finished. steps = 1918. Current max Steps = 2406
# finished. steps = 1758. Current max Steps = 2406
# finished. steps = 1906. Current max Steps = 2406
# finished. steps = 2046. Current max Steps = 2406
# finished. steps = 2038. Current max Steps = 2406
# finished. steps = 1754. Current max Steps = 2406
# finished. steps = 1902. Current max Steps = 2406
# finished. steps = 2042. Current max Steps = 2406
# finished. steps = 1862. Current max Steps = 2406
# finished. steps = 2010. Current max Steps = 2406
# finished. steps = 1794. Current max Steps = 2406
# finished. steps = 1942. Current max Steps = 2406
# finished. steps = 2082. Current max Steps = 2406
# finished. steps = 2074. Current max Steps = 2406
# finished. steps = 1790. Current max Steps = 2406
# finished. steps = 1938. Current max Steps = 2406
# finished. steps = 2078. Current max Steps = 2406
# finished. steps = 1898. Current max Steps = 2406
# finished. steps = 2046. Current max Steps = 2406
# finished. steps = 1734. Current max Steps = 2406
# finished. steps = 1882. Current max Steps = 2406
# finished. steps = 2022. Current max Steps = 2406
# finished. steps = 1842. Current max Steps = 2406
# finished. steps = 1990. Current max Steps = 2406
# finished. steps = 1654. Current max Steps = 2406
# finished. steps = 1802. Current max Steps = 2406
# finished. steps = 1766. Current max Steps = 2406
# finished. steps = 1914. Current max Steps = 2406
# finished. steps = 2054. Current max Steps = 2406
# finished. steps = 2046. Current max Steps = 2406
# finished. steps = 1762. Current max Steps = 2406
# finished. steps = 1910. Current max Steps = 2406
# finished. steps = 2050. Current max Steps = 2406
# finished. steps = 1870. Current max Steps = 2406
# finished. steps = 2018. Current max Steps = 2406
# finished. steps = 1706. Current max Steps = 2406
# finished. steps = 1854. Current max Steps = 2406
# finished. steps = 1994. Current max Steps = 2406
# finished. steps = 1814. Current max Steps = 2406
# finished. steps = 1962. Current max Steps = 2406
# finished. steps = 1626. Current max Steps = 2406
# finished. steps = 1774. Current max Steps = 2406
# finished. steps = 1642. Current max Steps = 2406
# finished. steps = 1790. Current max Steps = 2406
# finished. steps = 1930. Current max Steps = 2406
# finished. steps = 1750. Current max Steps = 2406
# finished. steps = 1898. Current max Steps = 2406
# finished. steps = 1562. Current max Steps = 2406
# finished. steps = 1710. Current max Steps = 2406
# finished. steps = 1814. Current max Steps = 2406
# finished. steps = 1962. Current max Steps = 2406
# finished. steps = 1434. Current max Steps = 2406
# finished. steps = 1582. Current max Steps = 2406
# finished. steps = 1722. Current max Steps = 2406
# finished. steps = 1714. Current max Steps = 2406
# finished. steps = 1726. Current max Steps = 2406
# finished. steps = 1566. Current max Steps = 2406
# finished. steps = 1714. Current max Steps = 2406
# finished. steps = 1854. Current max Steps = 2406
# finished. steps = 1846. Current max Steps = 2406
# finished. steps = 1562. Current max Steps = 2406
# finished. steps = 1710. Current max Steps = 2406
# finished. steps = 1850. Current max Steps = 2406
# finished. steps = 1670. Current max Steps = 2406
# finished. steps = 1818. Current max Steps = 2406
# finished. steps = 1602. Current max Steps = 2406
# finished. steps = 1750. Current max Steps = 2406
# finished. steps = 1890. Current max Steps = 2406
# finished. steps = 1882. Current max Steps = 2406
# finished. steps = 1598. Current max Steps = 2406
# finished. steps = 1746. Current max Steps = 2406
# finished. steps = 1886. Current max Steps = 2406
# finished. steps = 1706. Current max Steps = 2406
# finished. steps = 1854. Current max Steps = 2406
# finished. steps = 1542. Current max Steps = 2406
# finished. steps = 1690. Current max Steps = 2406
# finished. steps = 1830. Current max Steps = 2406
# finished. steps = 1650. Current max Steps = 2406
# finished. steps = 1798. Current max Steps = 2406
# finished. steps = 1462. Current max Steps = 2406
# finished. steps = 1610. Current max Steps = 2406
# finished. steps = 1574. Current max Steps = 2406
# finished. steps = 1722. Current max Steps = 2406
# finished. steps = 1862. Current max Steps = 2406
# finished. steps = 1854. Current max Steps = 2406
# finished. steps = 1570. Current max Steps = 2406
# finished. steps = 1718. Current max Steps = 2406
# finished. steps = 1858. Current max Steps = 2406
# finished. steps = 1678. Current max Steps = 2406
# finished. steps = 1826. Current max Steps = 2406
# finished. steps = 1514. Current max Steps = 2406
# finished. steps = 1662. Current max Steps = 2406
# finished. steps = 1802. Current max Steps = 2406
# finished. steps = 1622. Current max Steps = 2406
# finished. steps = 1770. Current max Steps = 2406
# finished. steps = 1434. Current max Steps = 2406
# finished. steps = 1582. Current max Steps = 2406
# finished. steps = 1450. Current max Steps = 2406
# finished. steps = 1598. Current max Steps = 2406
# finished. steps = 1738. Current max Steps = 2406
# finished. steps = 1558. Current max Steps = 2406
# finished. steps = 1706. Current max Steps = 2406
# finished. steps = 1370. Current max Steps = 2406
# finished. steps = 1518. Current max Steps = 2406
# finished. steps = 1622. Current max Steps = 2406
# finished. steps = 1770. Current max Steps = 2406
# finished. steps = 1670. Current max Steps = 2406
# finished. steps = 1818. Current max Steps = 2406
# finished. steps = 1958. Current max Steps = 2406
# finished. steps = 1950. Current max Steps = 2406
# finished. steps = 1666. Current max Steps = 2406
# finished. steps = 1814. Current max Steps = 2406
# finished. steps = 1954. Current max Steps = 2406
# finished. steps = 1774. Current max Steps = 2406
# finished. steps = 1922. Current max Steps = 2406
# finished. steps = 1610. Current max Steps = 2406
# finished. steps = 1758. Current max Steps = 2406
# finished. steps = 1898. Current max Steps = 2406
# finished. steps = 1718. Current max Steps = 2406
# finished. steps = 1866. Current max Steps = 2406
# finished. steps = 1530. Current max Steps = 2406
# finished. steps = 1678. Current max Steps = 2406
# finished. steps = 1546. Current max Steps = 2406
# finished. steps = 1694. Current max Steps = 2406
# finished. steps = 1834. Current max Steps = 2406
# finished. steps = 1654. Current max Steps = 2406
# finished. steps = 1802. Current max Steps = 2406
# finished. steps = 1466. Current max Steps = 2406
# finished. steps = 1614. Current max Steps = 2406
# finished. steps = 1718. Current max Steps = 2406
# finished. steps = 1866. Current max Steps = 2406
# finished. steps = 1666. Current max Steps = 2406
# finished. steps = 1814. Current max Steps = 2406
# finished. steps = 1954. Current max Steps = 2406
# finished. steps = 1774. Current max Steps = 2406
# finished. steps = 1922. Current max Steps = 2406
# finished. steps = 1586. Current max Steps = 2406
# finished. steps = 1734. Current max Steps = 2406
# finished. steps = 1838. Current max Steps = 2406
# finished. steps = 1986. Current max Steps = 2406
# finished. steps = 1774. Current max Steps = 2406
# finished. steps = 1922. Current max Steps = 2406
# finished. steps = 2370. Current max Steps = 2406
# finished. steps = 2398. Current max Steps = 2406
# finished. steps = 2546. Current max Steps = 2546
# finished. steps = 2334. Current max Steps = 2546
# finished. steps = 2482. Current max Steps = 2546
# finished. steps = 2622. Current max Steps = 2622
# finished. steps = 2326. Current max Steps = 2622
# finished. steps = 2474. Current max Steps = 2622
# finished. steps = 2614. Current max Steps = 2622
# finished. steps = 2606. Current max Steps = 2622
# finished. steps = 2574. Current max Steps = 2622
# finished. steps = 2418. Current max Steps = 2622
# finished. steps = 2490. Current max Steps = 2622
# finished. steps = 2454. Current max Steps = 2622
# finished. steps = 2526. Current max Steps = 2622
# finished. steps = 2558. Current max Steps = 2622
# finished. steps = 2262. Current max Steps = 2622
# finished. steps = 2334. Current max Steps = 2622
# finished. steps = 2366. Current max Steps = 2622
# finished. steps = 2378. Current max Steps = 2622
# finished. steps = 2666. Current max Steps = 2666
# finished. steps = 2466. Current max Steps = 2666
# finished. steps = 2614. Current max Steps = 2666
# finished. steps = 2462. Current max Steps = 2666
# finished. steps = 2610. Current max Steps = 2666
# finished. steps = 2398. Current max Steps = 2666
# finished. steps = 2546. Current max Steps = 2666
# finished. steps = 2362. Current max Steps = 2666
# finished. steps = 2510. Current max Steps = 2666
# finished. steps = 2650. Current max Steps = 2666
# finished. steps = 2642. Current max Steps = 2666
# finished. steps = 2358. Current max Steps = 2666
# finished. steps = 2506. Current max Steps = 2666
# finished. steps = 2646. Current max Steps = 2666
# finished. steps = 2466. Current max Steps = 2666
# finished. steps = 2614. Current max Steps = 2666
# finished. steps = 2466. Current max Steps = 2666
# finished. steps = 2614. Current max Steps = 2666
# finished. steps = 2754. Current max Steps = 2754
# finished. steps = 2574. Current max Steps = 2754
# finished. steps = 2722. Current max Steps = 2754
# finished. steps = 2354. Current max Steps = 2754
# finished. steps = 2502. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2238. Current max Steps = 2754
# finished. steps = 2266. Current max Steps = 2754
# finished. steps = 2414. Current max Steps = 2754
# finished. steps = 2250. Current max Steps = 2754
# finished. steps = 2278. Current max Steps = 2754
# finished. steps = 2426. Current max Steps = 2754
# finished. steps = 2214. Current max Steps = 2754
# finished. steps = 2362. Current max Steps = 2754
# finished. steps = 2502. Current max Steps = 2754
# finished. steps = 2218. Current max Steps = 2754
# finished. steps = 2366. Current max Steps = 2754
# finished. steps = 2506. Current max Steps = 2754
# finished. steps = 2326. Current max Steps = 2754
# finished. steps = 2474. Current max Steps = 2754
# finished. steps = 2106. Current max Steps = 2754
# finished. steps = 2254. Current max Steps = 2754
# finished. steps = 1998. Current max Steps = 2754
# finished. steps = 1990. Current max Steps = 2754
# finished. steps = 2018. Current max Steps = 2754
# finished. steps = 2166. Current max Steps = 2754
# finished. steps = 2002. Current max Steps = 2754
# finished. steps = 2030. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 1966. Current max Steps = 2754
# finished. steps = 2114. Current max Steps = 2754
# finished. steps = 2254. Current max Steps = 2754
# finished. steps = 2474. Current max Steps = 2754
# finished. steps = 2238. Current max Steps = 2754
# finished. steps = 2386. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2122. Current max Steps = 2754
# finished. steps = 2150. Current max Steps = 2754
# finished. steps = 2298. Current max Steps = 2754
# finished. steps = 2250. Current max Steps = 2754
# finished. steps = 2126. Current max Steps = 2754
# finished. steps = 2534. Current max Steps = 2754
# finished. steps = 2062. Current max Steps = 2754
# finished. steps = 2210. Current max Steps = 2754
# finished. steps = 2350. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 2318. Current max Steps = 2754
# finished. steps = 1950. Current max Steps = 2754
# finished. steps = 2098. Current max Steps = 2754
# finished. steps = 1842. Current max Steps = 2754
# finished. steps = 1834. Current max Steps = 2754
# finished. steps = 1862. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 1846. Current max Steps = 2754
# finished. steps = 1874. Current max Steps = 2754
# finished. steps = 2022. Current max Steps = 2754
# finished. steps = 1810. Current max Steps = 2754
# finished. steps = 1958. Current max Steps = 2754
# finished. steps = 2098. Current max Steps = 2754
# finished. steps = 2078. Current max Steps = 2754
# finished. steps = 2226. Current max Steps = 2754
# finished. steps = 2366. Current max Steps = 2754
# finished. steps = 2358. Current max Steps = 2754
# finished. steps = 2370. Current max Steps = 2754
# finished. steps = 2318. Current max Steps = 2754
# finished. steps = 2082. Current max Steps = 2754
# finished. steps = 2230. Current max Steps = 2754
# finished. steps = 1974. Current max Steps = 2754
# finished. steps = 1966. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 2142. Current max Steps = 2754
# finished. steps = 2094. Current max Steps = 2754
# finished. steps = 1970. Current max Steps = 2754
# finished. steps = 2378. Current max Steps = 2754
# finished. steps = 2354. Current max Steps = 2754
# finished. steps = 2118. Current max Steps = 2754
# finished. steps = 2266. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 2002. Current max Steps = 2754
# finished. steps = 2030. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 1954. Current max Steps = 2754
# finished. steps = 2102. Current max Steps = 2754
# finished. steps = 2242. Current max Steps = 2754
# finished. steps = 2234. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2006. Current max Steps = 2754
# finished. steps = 2414. Current max Steps = 2754
# finished. steps = 2074. Current max Steps = 2754
# finished. steps = 1950. Current max Steps = 2754
# finished. steps = 2014. Current max Steps = 2754
# finished. steps = 2162. Current max Steps = 2754
# finished. steps = 2302. Current max Steps = 2754
# finished. steps = 2294. Current max Steps = 2754
# finished. steps = 2358. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 1834. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 2122. Current max Steps = 2754
# finished. steps = 2098. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2386. Current max Steps = 2754
# finished. steps = 2206. Current max Steps = 2754
# finished. steps = 2354. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 2134. Current max Steps = 2754
# finished. steps = 1878. Current max Steps = 2754
# finished. steps = 1870. Current max Steps = 2754
# finished. steps = 1898. Current max Steps = 2754
# finished. steps = 2046. Current max Steps = 2754
# finished. steps = 1882. Current max Steps = 2754
# finished. steps = 1910. Current max Steps = 2754
# finished. steps = 2058. Current max Steps = 2754
# finished. steps = 1846. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 2134. Current max Steps = 2754
# finished. steps = 2114. Current max Steps = 2754
# finished. steps = 2262. Current max Steps = 2754
# finished. steps = 2402. Current max Steps = 2754
# finished. steps = 2394. Current max Steps = 2754
# finished. steps = 2406. Current max Steps = 2754
# finished. steps = 2354. Current max Steps = 2754
# finished. steps = 2118. Current max Steps = 2754
# finished. steps = 2266. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 2002. Current max Steps = 2754
# finished. steps = 2030. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2006. Current max Steps = 2754
# finished. steps = 2414. Current max Steps = 2754
# finished. steps = 2146. Current max Steps = 2754
# finished. steps = 2294. Current max Steps = 2754
# finished. steps = 2434. Current max Steps = 2754
# finished. steps = 2426. Current max Steps = 2754
# finished. steps = 2438. Current max Steps = 2754
# finished. steps = 1898. Current max Steps = 2754
# finished. steps = 2046. Current max Steps = 2754
# finished. steps = 2186. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 2190. Current max Steps = 2754
# finished. steps = 2030. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 2318. Current max Steps = 2754
# finished. steps = 2310. Current max Steps = 2754
# finished. steps = 2026. Current max Steps = 2754
# finished. steps = 2174. Current max Steps = 2754
# finished. steps = 2314. Current max Steps = 2754
# finished. steps = 2134. Current max Steps = 2754
# finished. steps = 2282. Current max Steps = 2754
# finished. steps = 2390. Current max Steps = 2754
# finished. steps = 2154. Current max Steps = 2754
# finished. steps = 2302. Current max Steps = 2754
# finished. steps = 2046. Current max Steps = 2754
# finished. steps = 2038. Current max Steps = 2754
# finished. steps = 2066. Current max Steps = 2754
# finished. steps = 2214. Current max Steps = 2754
# finished. steps = 1990. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 2278. Current max Steps = 2754
# finished. steps = 2270. Current max Steps = 2754
# finished. steps = 2282. Current max Steps = 2754
# finished. steps = 2166. Current max Steps = 2754
# finished. steps = 2042. Current max Steps = 2754
# finished. steps = 2450. Current max Steps = 2754
# finished. steps = 2110. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 2050. Current max Steps = 2754
# finished. steps = 2198. Current max Steps = 2754
# finished. steps = 2338. Current max Steps = 2754
# finished. steps = 2330. Current max Steps = 2754
# finished. steps = 2394. Current max Steps = 2754
# finished. steps = 2206. Current max Steps = 2754
# finished. steps = 1870. Current max Steps = 2754
# finished. steps = 2018. Current max Steps = 2754
# finished. steps = 2158. Current max Steps = 2754
# finished. steps = 2362. Current max Steps = 2754
# finished. steps = 2126. Current max Steps = 2754
# finished. steps = 2274. Current max Steps = 2754
# finished. steps = 2018. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 2038. Current max Steps = 2754
# finished. steps = 2186. Current max Steps = 2754
# finished. steps = 1962. Current max Steps = 2754
# finished. steps = 2110. Current max Steps = 2754
# finished. steps = 2250. Current max Steps = 2754
# finished. steps = 2242. Current max Steps = 2754
# finished. steps = 2254. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 2014. Current max Steps = 2754
# finished. steps = 2422. Current max Steps = 2754
# finished. steps = 2042. Current max Steps = 2754
# finished. steps = 2190. Current max Steps = 2754
# finished. steps = 2330. Current max Steps = 2754
# finished. steps = 2322. Current max Steps = 2754
# finished. steps = 2334. Current max Steps = 2754
# finished. steps = 2174. Current max Steps = 2754
# finished. steps = 2322. Current max Steps = 2754
# finished. steps = 2462. Current max Steps = 2754
# finished. steps = 2454. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 2318. Current max Steps = 2754
# finished. steps = 2458. Current max Steps = 2754
# finished. steps = 2278. Current max Steps = 2754
# finished. steps = 2426. Current max Steps = 2754
# finished. steps = 2082. Current max Steps = 2754
# finished. steps = 1958. Current max Steps = 2754
# finished. steps = 2022. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 2310. Current max Steps = 2754
# finished. steps = 2302. Current max Steps = 2754
# finished. steps = 2366. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 1842. Current max Steps = 2754
# finished. steps = 1990. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2018. Current max Steps = 2754
# finished. steps = 1894. Current max Steps = 2754
# finished. steps = 1958. Current max Steps = 2754
# finished. steps = 2106. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2238. Current max Steps = 2754
# finished. steps = 2302. Current max Steps = 2754
# finished. steps = 1818. Current max Steps = 2754
# finished. steps = 1966. Current max Steps = 2754
# finished. steps = 2106. Current max Steps = 2754
# finished. steps = 2098. Current max Steps = 2754
# finished. steps = 1814. Current max Steps = 2754
# finished. steps = 1962. Current max Steps = 2754
# finished. steps = 2102. Current max Steps = 2754
# finished. steps = 1922. Current max Steps = 2754
# finished. steps = 2070. Current max Steps = 2754
# finished. steps = 2114. Current max Steps = 2754
# finished. steps = 1778. Current max Steps = 2754
# finished. steps = 1926. Current max Steps = 2754
# finished. steps = 2066. Current max Steps = 2754
# finished. steps = 2366. Current max Steps = 2754
# finished. steps = 2030. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 2318. Current max Steps = 2754
# finished. steps = 2090. Current max Steps = 2754
# finished. steps = 2238. Current max Steps = 2754
# finished. steps = 2378. Current max Steps = 2754
# finished. steps = 2198. Current max Steps = 2754
# finished. steps = 2346. Current max Steps = 2754
# finished. steps = 1906. Current max Steps = 2754
# finished. steps = 2054. Current max Steps = 2754
# finished. steps = 2194. Current max Steps = 2754
# finished. steps = 2014. Current max Steps = 2754
# finished. steps = 2162. Current max Steps = 2754
# finished. steps = 1794. Current max Steps = 2754
# finished. steps = 1942. Current max Steps = 2754
# finished. steps = 1686. Current max Steps = 2754
# finished. steps = 1678. Current max Steps = 2754
# finished. steps = 1706. Current max Steps = 2754
# finished. steps = 1854. Current max Steps = 2754
# finished. steps = 1690. Current max Steps = 2754
# finished. steps = 1718. Current max Steps = 2754
# finished. steps = 1866. Current max Steps = 2754
# finished. steps = 1654. Current max Steps = 2754
# finished. steps = 1802. Current max Steps = 2754
# finished. steps = 1942. Current max Steps = 2754
# finished. steps = 1922. Current max Steps = 2754
# finished. steps = 2070. Current max Steps = 2754
# finished. steps = 2210. Current max Steps = 2754
# finished. steps = 2202. Current max Steps = 2754
# finished. steps = 2214. Current max Steps = 2754
# finished. steps = 2162. Current max Steps = 2754
# finished. steps = 1926. Current max Steps = 2754
# finished. steps = 2074. Current max Steps = 2754
# finished. steps = 1818. Current max Steps = 2754
# finished. steps = 1810. Current max Steps = 2754
# finished. steps = 1838. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 1938. Current max Steps = 2754
# finished. steps = 1814. Current max Steps = 2754
# finished. steps = 2222. Current max Steps = 2754
# finished. steps = 1954. Current max Steps = 2754
# finished. steps = 2102. Current max Steps = 2754
# finished. steps = 2242. Current max Steps = 2754
# finished. steps = 2234. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 1706. Current max Steps = 2754
# finished. steps = 1854. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 1998. Current max Steps = 2754
# finished. steps = 1838. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 2126. Current max Steps = 2754
# finished. steps = 2118. Current max Steps = 2754
# finished. steps = 1834. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 2122. Current max Steps = 2754
# finished. steps = 1942. Current max Steps = 2754
# finished. steps = 2090. Current max Steps = 2754
# finished. steps = 2198. Current max Steps = 2754
# finished. steps = 1962. Current max Steps = 2754
# finished. steps = 2110. Current max Steps = 2754
# finished. steps = 1854. Current max Steps = 2754
# finished. steps = 1846. Current max Steps = 2754
# finished. steps = 1874. Current max Steps = 2754
# finished. steps = 2022. Current max Steps = 2754
# finished. steps = 1798. Current max Steps = 2754
# finished. steps = 1946. Current max Steps = 2754
# finished. steps = 2086. Current max Steps = 2754
# finished. steps = 2078. Current max Steps = 2754
# finished. steps = 2090. Current max Steps = 2754
# finished. steps = 1974. Current max Steps = 2754
# finished. steps = 1850. Current max Steps = 2754
# finished. steps = 2258. Current max Steps = 2754
# finished. steps = 1918. Current max Steps = 2754
# finished. steps = 1794. Current max Steps = 2754
# finished. steps = 1858. Current max Steps = 2754
# finished. steps = 2006. Current max Steps = 2754
# finished. steps = 2146. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 2202. Current max Steps = 2754
# finished. steps = 2014. Current max Steps = 2754
# finished. steps = 1678. Current max Steps = 2754
# finished. steps = 1826. Current max Steps = 2754
# finished. steps = 1966. Current max Steps = 2754
# finished. steps = 1966. Current max Steps = 2754
# finished. steps = 2114. Current max Steps = 2754
# finished. steps = 2254. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2258. Current max Steps = 2754
# finished. steps = 1718. Current max Steps = 2754
# finished. steps = 1866. Current max Steps = 2754
# finished. steps = 2006. Current max Steps = 2754
# finished. steps = 1998. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 1850. Current max Steps = 2754
# finished. steps = 1998. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 1846. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 2134. Current max Steps = 2754
# finished. steps = 1954. Current max Steps = 2754
# finished. steps = 2102. Current max Steps = 2754
# finished. steps = 1562. Current max Steps = 2754
# finished. steps = 1710. Current max Steps = 2754
# finished. steps = 1850. Current max Steps = 2754
# finished. steps = 1842. Current max Steps = 2754
# finished. steps = 1854. Current max Steps = 2754
# finished. steps = 1694. Current max Steps = 2754
# finished. steps = 1842. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 1974. Current max Steps = 2754
# finished. steps = 1690. Current max Steps = 2754
# finished. steps = 1838. Current max Steps = 2754
# finished. steps = 1978. Current max Steps = 2754
# finished. steps = 1798. Current max Steps = 2754
# finished. steps = 1946. Current max Steps = 2754
# finished. steps = 1730. Current max Steps = 2754
# finished. steps = 1878. Current max Steps = 2754
# finished. steps = 2018. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 1726. Current max Steps = 2754
# finished. steps = 1874. Current max Steps = 2754
# finished. steps = 2014. Current max Steps = 2754
# finished. steps = 1834. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 1670. Current max Steps = 2754
# finished. steps = 1818. Current max Steps = 2754
# finished. steps = 1958. Current max Steps = 2754
# finished. steps = 1778. Current max Steps = 2754
# finished. steps = 1926. Current max Steps = 2754
# finished. steps = 1590. Current max Steps = 2754
# finished. steps = 1738. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 1934. Current max Steps = 2754
# finished. steps = 2082. Current max Steps = 2754
# finished. steps = 1826. Current max Steps = 2754
# finished. steps = 1818. Current max Steps = 2754
# finished. steps = 1846. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 1770. Current max Steps = 2754
# finished. steps = 1918. Current max Steps = 2754
# finished. steps = 2058. Current max Steps = 2754
# finished. steps = 2050. Current max Steps = 2754
# finished. steps = 2062. Current max Steps = 2754
# finished. steps = 1946. Current max Steps = 2754
# finished. steps = 1822. Current max Steps = 2754
# finished. steps = 2230. Current max Steps = 2754
# finished. steps = 1850. Current max Steps = 2754
# finished. steps = 1998. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2142. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2270. Current max Steps = 2754
# finished. steps = 2262. Current max Steps = 2754
# finished. steps = 1978. Current max Steps = 2754
# finished. steps = 2126. Current max Steps = 2754
# finished. steps = 2266. Current max Steps = 2754
# finished. steps = 2086. Current max Steps = 2754
# finished. steps = 2234. Current max Steps = 2754
# finished. steps = 1890. Current max Steps = 2754
# finished. steps = 1766. Current max Steps = 2754
# finished. steps = 1830. Current max Steps = 2754
# finished. steps = 1978. Current max Steps = 2754
# finished. steps = 2118. Current max Steps = 2754
# finished. steps = 2110. Current max Steps = 2754
# finished. steps = 2174. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 1650. Current max Steps = 2754
# finished. steps = 1798. Current max Steps = 2754
# finished. steps = 1938. Current max Steps = 2754
# finished. steps = 1826. Current max Steps = 2754
# finished. steps = 1702. Current max Steps = 2754
# finished. steps = 1766. Current max Steps = 2754
# finished. steps = 1914. Current max Steps = 2754
# finished. steps = 2054. Current max Steps = 2754
# finished. steps = 2046. Current max Steps = 2754
# finished. steps = 2110. Current max Steps = 2754
# finished. steps = 1626. Current max Steps = 2754
# finished. steps = 1774. Current max Steps = 2754
# finished. steps = 1914. Current max Steps = 2754
# finished. steps = 1906. Current max Steps = 2754
# finished. steps = 1622. Current max Steps = 2754
# finished. steps = 1770. Current max Steps = 2754
# finished. steps = 1910. Current max Steps = 2754
# finished. steps = 1730. Current max Steps = 2754
# finished. steps = 1878. Current max Steps = 2754
# finished. steps = 1922. Current max Steps = 2754
# finished. steps = 1586. Current max Steps = 2754
# finished. steps = 1734. Current max Steps = 2754
# finished. steps = 1874. Current max Steps = 2754
# finished. steps = 2174. Current max Steps = 2754
# finished. steps = 1838. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 2126. Current max Steps = 2754
# finished. steps = 1898. Current max Steps = 2754
# finished. steps = 2046. Current max Steps = 2754
# finished. steps = 2186. Current max Steps = 2754
# finished. steps = 2006. Current max Steps = 2754
# finished. steps = 2154. Current max Steps = 2754
# finished. steps = 2266. Current max Steps = 2754
# finished. steps = 2030. Current max Steps = 2754
# finished. steps = 2178. Current max Steps = 2754
# finished. steps = 1922. Current max Steps = 2754
# finished. steps = 1914. Current max Steps = 2754
# finished. steps = 1942. Current max Steps = 2754
# finished. steps = 2090. Current max Steps = 2754
# finished. steps = 1866. Current max Steps = 2754
# finished. steps = 2014. Current max Steps = 2754
# finished. steps = 2154. Current max Steps = 2754
# finished. steps = 2146. Current max Steps = 2754
# finished. steps = 2158. Current max Steps = 2754
# finished. steps = 2042. Current max Steps = 2754
# finished. steps = 1918. Current max Steps = 2754
# finished. steps = 2326. Current max Steps = 2754
# finished. steps = 1946. Current max Steps = 2754
# finished. steps = 2094. Current max Steps = 2754
# finished. steps = 2234. Current max Steps = 2754
# finished. steps = 2226. Current max Steps = 2754
# finished. steps = 2238. Current max Steps = 2754
# finished. steps = 2078. Current max Steps = 2754
# finished. steps = 2226. Current max Steps = 2754
# finished. steps = 2366. Current max Steps = 2754
# finished. steps = 2358. Current max Steps = 2754
# finished. steps = 2074. Current max Steps = 2754
# finished. steps = 2222. Current max Steps = 2754
# finished. steps = 2362. Current max Steps = 2754
# finished. steps = 2182. Current max Steps = 2754
# finished. steps = 2330. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 1862. Current max Steps = 2754
# finished. steps = 1926. Current max Steps = 2754
# finished. steps = 2074. Current max Steps = 2754
# finished. steps = 2214. Current max Steps = 2754
# finished. steps = 2206. Current max Steps = 2754
# finished. steps = 2270. Current max Steps = 2754
# finished. steps = 2082. Current max Steps = 2754
# finished. steps = 1746. Current max Steps = 2754
# finished. steps = 1894. Current max Steps = 2754
# finished. steps = 2034. Current max Steps = 2754
# finished. steps = 1966. Current max Steps = 2754
# finished. steps = 2114. Current max Steps = 2754
# finished. steps = 2254. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2258. Current max Steps = 2754
# finished. steps = 2098. Current max Steps = 2754
# finished. steps = 2246. Current max Steps = 2754
# finished. steps = 2386. Current max Steps = 2754
# finished. steps = 2378. Current max Steps = 2754
# finished. steps = 2094. Current max Steps = 2754
# finished. steps = 2242. Current max Steps = 2754
# finished. steps = 2382. Current max Steps = 2754
# finished. steps = 2202. Current max Steps = 2754
# finished. steps = 2350. Current max Steps = 2754
# finished. steps = 2134. Current max Steps = 2754
# finished. steps = 2282. Current max Steps = 2754
# finished. steps = 2422. Current max Steps = 2754
# finished. steps = 2414. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2278. Current max Steps = 2754
# finished. steps = 2418. Current max Steps = 2754
# finished. steps = 2238. Current max Steps = 2754
# finished. steps = 2386. Current max Steps = 2754
# finished. steps = 2074. Current max Steps = 2754
# finished. steps = 2222. Current max Steps = 2754
# finished. steps = 2362. Current max Steps = 2754
# finished. steps = 2182. Current max Steps = 2754
# finished. steps = 2330. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 2142. Current max Steps = 2754
# finished. steps = 1922. Current max Steps = 2754
# finished. steps = 1798. Current max Steps = 2754
# finished. steps = 1862. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 2150. Current max Steps = 2754
# finished. steps = 2142. Current max Steps = 2754
# finished. steps = 2206. Current max Steps = 2754
# finished. steps = 1722. Current max Steps = 2754
# finished. steps = 1870. Current max Steps = 2754
# finished. steps = 2010. Current max Steps = 2754
# finished. steps = 2002. Current max Steps = 2754
# finished. steps = 1718. Current max Steps = 2754
# finished. steps = 1866. Current max Steps = 2754
# finished. steps = 2006. Current max Steps = 2754
# finished. steps = 1826. Current max Steps = 2754
# finished. steps = 1974. Current max Steps = 2754
# finished. steps = 2018. Current max Steps = 2754
# finished. steps = 1682. Current max Steps = 2754
# finished. steps = 1830. Current max Steps = 2754
# finished. steps = 1970. Current max Steps = 2754
# finished. steps = 2270. Current max Steps = 2754
# finished. steps = 1934. Current max Steps = 2754
# finished. steps = 2082. Current max Steps = 2754
# finished. steps = 2222. Current max Steps = 2754
# finished. steps = 1994. Current max Steps = 2754
# finished. steps = 2142. Current max Steps = 2754
# finished. steps = 2282. Current max Steps = 2754
# finished. steps = 2102. Current max Steps = 2754
# finished. steps = 2250. Current max Steps = 2754
# finished. steps = 2042. Current max Steps = 2754
# finished. steps = 1918. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2270. Current max Steps = 2754
# finished. steps = 2262. Current max Steps = 2754
# finished. steps = 2326. Current max Steps = 2754
# finished. steps = 1842. Current max Steps = 2754
# finished. steps = 1990. Current max Steps = 2754
# finished. steps = 2130. Current max Steps = 2754
# finished. steps = 2122. Current max Steps = 2754
# finished. steps = 1838. Current max Steps = 2754
# finished. steps = 1986. Current max Steps = 2754
# finished. steps = 2126. Current max Steps = 2754
# finished. steps = 1946. Current max Steps = 2754
# finished. steps = 2094. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 1802. Current max Steps = 2754
# finished. steps = 1950. Current max Steps = 2754
# finished. steps = 2090. Current max Steps = 2754
# finished. steps = 1974. Current max Steps = 2754
# finished. steps = 2122. Current max Steps = 2754
# finished. steps = 2262. Current max Steps = 2754
# finished. steps = 2254. Current max Steps = 2754
# finished. steps = 1970. Current max Steps = 2754
# finished. steps = 2118. Current max Steps = 2754
# finished. steps = 2258. Current max Steps = 2754
# finished. steps = 2078. Current max Steps = 2754
# finished. steps = 2226. Current max Steps = 2754
# finished. steps = 1914. Current max Steps = 2754
# finished. steps = 2062. Current max Steps = 2754
# finished. steps = 2202. Current max Steps = 2754
# finished. steps = 2022. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 1834. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 2390. Current max Steps = 2754
# finished. steps = 2054. Current max Steps = 2754
# finished. steps = 2202. Current max Steps = 2754
# finished. steps = 2342. Current max Steps = 2754
# finished. steps = 2114. Current max Steps = 2754
# finished. steps = 2262. Current max Steps = 2754
# finished. steps = 2402. Current max Steps = 2754
# finished. steps = 2222. Current max Steps = 2754
# finished. steps = 2370. Current max Steps = 2754
# finished. steps = 2326. Current max Steps = 2754
# finished. steps = 1990. Current max Steps = 2754
# finished. steps = 2138. Current max Steps = 2754
# finished. steps = 2278. Current max Steps = 2754
# finished. steps = 2050. Current max Steps = 2754
# finished. steps = 2198. Current max Steps = 2754
# finished. steps = 2338. Current max Steps = 2754
# finished. steps = 2158. Current max Steps = 2754
# finished. steps = 2306. Current max Steps = 2754
# finished. steps = 1914. Current max Steps = 2754
# finished. steps = 2062. Current max Steps = 2754
# finished. steps = 2202. Current max Steps = 2754
# finished. steps = 2022. Current max Steps = 2754
# finished. steps = 2170. Current max Steps = 2754
# finished. steps = 1834. Current max Steps = 2754
# finished. steps = 1982. Current max Steps = 2754
# finished. steps = 2758. Current max Steps = 2758
# finished. steps = 2906. Current max Steps = 2906
# finished. steps = 2806. Current max Steps = 2906
# finished. steps = 2954. Current max Steps = 2954
# finished. steps = 3094. Current max Steps = 3094
# finished. steps = 2914. Current max Steps = 3094
# finished. steps = 3062. Current max Steps = 3094
# finished. steps = 2694. Current max Steps = 3094
# finished. steps = 2842. Current max Steps = 3094
# finished. steps = 2586. Current max Steps = 3094
# finished. steps = 2694. Current max Steps = 3094
# finished. steps = 2842. Current max Steps = 3094
# finished. steps = 2982. Current max Steps = 3094
# finished. steps = 2974. Current max Steps = 3094
# finished. steps = 2690. Current max Steps = 3094
# finished. steps = 2838. Current max Steps = 3094
# finished. steps = 2978. Current max Steps = 3094
# finished. steps = 2798. Current max Steps = 3094
# finished. steps = 2946. Current max Steps = 3094
# finished. steps = 2798. Current max Steps = 3094
# finished. steps = 2946. Current max Steps = 3094
# finished. steps = 3086. Current max Steps = 3094
# finished. steps = 2906. Current max Steps = 3094
# finished. steps = 3054. Current max Steps = 3094
# finished. steps = 2686. Current max Steps = 3094
# finished. steps = 2834. Current max Steps = 3094
# finished. steps = 2578. Current max Steps = 3094
# finished. steps = 2570. Current max Steps = 3094
# finished. steps = 2598. Current max Steps = 3094
# finished. steps = 2746. Current max Steps = 3094
# finished. steps = 2538. Current max Steps = 3094
# finished. steps = 2566. Current max Steps = 3094
# finished. steps = 2714. Current max Steps = 3094
# finished. steps = 2502. Current max Steps = 3094
# finished. steps = 2650. Current max Steps = 3094
# finished. steps = 2790. Current max Steps = 3094
# finished. steps = 3010. Current max Steps = 3094
# finished. steps = 2382. Current max Steps = 3094
# finished. steps = 2410. Current max Steps = 3094
# finished. steps = 2558. Current max Steps = 3094
# finished. steps = 2346. Current max Steps = 3094
# finished. steps = 2494. Current max Steps = 3094
# finished. steps = 2634. Current max Steps = 3094
# finished. steps = 2454. Current max Steps = 3094
# finished. steps = 2482. Current max Steps = 3094
# finished. steps = 2630. Current max Steps = 3094
# finished. steps = 2418. Current max Steps = 3094
# finished. steps = 2566. Current max Steps = 3094
# finished. steps = 2706. Current max Steps = 3094
# finished. steps = 2410. Current max Steps = 3094
# finished. steps = 2558. Current max Steps = 3094
# finished. steps = 2698. Current max Steps = 3094
# finished. steps = 2690. Current max Steps = 3094
# finished. steps = 2854. Current max Steps = 3094
# finished. steps = 2890. Current max Steps = 3094
# finished. steps = 2782. Current max Steps = 3094
# finished. steps = 2854. Current max Steps = 3094
# finished. steps = 2418. Current max Steps = 3094
# finished. steps = 2446. Current max Steps = 3094
# finished. steps = 2594. Current max Steps = 3094
# finished. steps = 2382. Current max Steps = 3094
# finished. steps = 2530. Current max Steps = 3094
# finished. steps = 2670. Current max Steps = 3094
# finished. steps = 2490. Current max Steps = 3094
# finished. steps = 2518. Current max Steps = 3094
# finished. steps = 2666. Current max Steps = 3094
# finished. steps = 2454. Current max Steps = 3094
# finished. steps = 2602. Current max Steps = 3094
# finished. steps = 2742. Current max Steps = 3094
# finished. steps = 2446. Current max Steps = 3094
# finished. steps = 2594. Current max Steps = 3094
# finished. steps = 2734. Current max Steps = 3094
# finished. steps = 2726. Current max Steps = 3094
# finished. steps = 2890. Current max Steps = 3094
# finished. steps = 2522. Current max Steps = 3094
# finished. steps = 2550. Current max Steps = 3094
# finished. steps = 2698. Current max Steps = 3094
# finished. steps = 2486. Current max Steps = 3094
# finished. steps = 2634. Current max Steps = 3094
# finished. steps = 2774. Current max Steps = 3094
# finished. steps = 2478. Current max Steps = 3094
# finished. steps = 2626. Current max Steps = 3094
# finished. steps = 2766. Current max Steps = 3094
# finished. steps = 2758. Current max Steps = 3094
# finished. steps = 2726. Current max Steps = 3094
# finished. steps = 2926. Current max Steps = 3094
# finished. steps = 2818. Current max Steps = 3094
# finished. steps = 2890. Current max Steps = 3094
# finished. steps = 2898. Current max Steps = 3094
# finished. steps = 2790. Current max Steps = 3094
# finished. steps = 2862. Current max Steps = 3094
# finished. steps = 2870. Current max Steps = 3094
# finished. steps = 2942. Current max Steps = 3094
# finished. steps = 2974. Current max Steps = 3094
# finished. steps = 2226. Current max Steps = 3094
# finished. steps = 2254. Current max Steps = 3094
# finished. steps = 2402. Current max Steps = 3094
# finished. steps = 2190. Current max Steps = 3094
# finished. steps = 2338. Current max Steps = 3094
# finished. steps = 2478. Current max Steps = 3094
# finished. steps = 2298. Current max Steps = 3094
# finished. steps = 2326. Current max Steps = 3094
# finished. steps = 2474. Current max Steps = 3094
# finished. steps = 2262. Current max Steps = 3094
# finished. steps = 2410. Current max Steps = 3094
# finished. steps = 2550. Current max Steps = 3094
# finished. steps = 2254. Current max Steps = 3094
# finished. steps = 2402. Current max Steps = 3094
# finished. steps = 2542. Current max Steps = 3094
# finished. steps = 2534. Current max Steps = 3094
# finished. steps = 2698. Current max Steps = 3094
# finished. steps = 2330. Current max Steps = 3094
# finished. steps = 2358. Current max Steps = 3094
# finished. steps = 2506. Current max Steps = 3094
# finished. steps = 2294. Current max Steps = 3094
# finished. steps = 2442. Current max Steps = 3094
# finished. steps = 2582. Current max Steps = 3094
# finished. steps = 2286. Current max Steps = 3094
# finished. steps = 2434. Current max Steps = 3094
# finished. steps = 2574. Current max Steps = 3094
# finished. steps = 2566. Current max Steps = 3094
# finished. steps = 2534. Current max Steps = 3094
# finished. steps = 2734. Current max Steps = 3094
# finished. steps = 2626. Current max Steps = 3094
# finished. steps = 2698. Current max Steps = 3094
# finished. steps = 2342. Current max Steps = 3094
# finished. steps = 2370. Current max Steps = 3094
# finished. steps = 2518. Current max Steps = 3094
# finished. steps = 2306. Current max Steps = 3094
# finished. steps = 2454. Current max Steps = 3094
# finished. steps = 2594. Current max Steps = 3094
# finished. steps = 2298. Current max Steps = 3094
# finished. steps = 2446. Current max Steps = 3094
# finished. steps = 2586. Current max Steps = 3094
# finished. steps = 2578. Current max Steps = 3094
# finished. steps = 2546. Current max Steps = 3094
# finished. steps = 2390. Current max Steps = 3094
# finished. steps = 2462. Current max Steps = 3094
# finished. steps = 2706. Current max Steps = 3094
# finished. steps = 2598. Current max Steps = 3094
# finished. steps = 2670. Current max Steps = 3094
# finished. steps = 2678. Current max Steps = 3094
# finished. steps = 2750. Current max Steps = 3094
# ...
# finished. steps = 4698. Current max Steps = 5378
# finished. steps = 4726. Current max Steps = 5378
# finished. steps = 4874. Current max Steps = 5378
# finished. steps = 4970. Current max Steps = 5378
# finished. steps = 4626. Current max Steps = 5378
# finished. steps = 5034. Current max Steps = 5378
# finished. steps = 4974. Current max Steps = 5378
# finished. steps = 5046. Current max Steps = 5378
# finished. steps = 4914. Current max Steps = 5378
# finished. steps = 4570. Current max Steps = 5378
# finished. steps = 5134. Current max Steps = 5378
# finished. steps = 4790. Current max Steps = 5378
# finished. steps = 4818. Current max Steps = 5378
# finished. steps = 4966. Current max Steps = 5378
# finished. steps = 4682. Current max Steps = 5378
# finished. steps = 4710. Current max Steps = 5378
# finished. steps = 4858. Current max Steps = 5378
# finished. steps = 4646. Current max Steps = 5378
# finished. steps = 4794. Current max Steps = 5378
# finished. steps = 4934. Current max Steps = 5378
# finished. steps = 4754. Current max Steps = 5378
# finished. steps = 4782. Current max Steps = 5378
# finished. steps = 4930. Current max Steps = 5378
# finished. steps = 4718. Current max Steps = 5378
# finished. steps = 4866. Current max Steps = 5378
# finished. steps = 5006. Current max Steps = 5378
# finished. steps = 4710. Current max Steps = 5378
# finished. steps = 4858. Current max Steps = 5378
# finished. steps = 4998. Current max Steps = 5378
# finished. steps = 4990. Current max Steps = 5378
# finished. steps = 4978. Current max Steps = 5378
# finished. steps = 4790. Current max Steps = 5378
# finished. steps = 4742. Current max Steps = 5378
# finished. steps = 4962. Current max Steps = 5378
# finished. steps = 4854. Current max Steps = 5378
# finished. steps = 4926. Current max Steps = 5378
# finished. steps = 4698. Current max Steps = 5378
# finished. steps = 4554. Current max Steps = 5378
# finished. steps = 4202. Current max Steps = 5378
# finished. steps = 4274. Current max Steps = 5378
# finished. steps = 4142. Current max Steps = 5378
# finished. steps = 4362. Current max Steps = 5378
# finished. steps = 4390. Current max Steps = 5378
# finished. steps = 4538. Current max Steps = 5378
# finished. steps = 4162. Current max Steps = 5378
# finished. steps = 4234. Current max Steps = 5378
# finished. steps = 4226. Current max Steps = 5378
# finished. steps = 4218. Current max Steps = 5378
# finished. steps = 4246. Current max Steps = 5378
# finished. steps = 4394. Current max Steps = 5378
# finished. steps = 4818. Current max Steps = 5378
# finished. steps = 4674. Current max Steps = 5378
# finished. steps = 4322. Current max Steps = 5378
# finished. steps = 4394. Current max Steps = 5378
# finished. steps = 4262. Current max Steps = 5378
# finished. steps = 4482. Current max Steps = 5378
# finished. steps = 4510. Current max Steps = 5378
# finished. steps = 4658. Current max Steps = 5378
# finished. steps = 4282. Current max Steps = 5378
# finished. steps = 4354. Current max Steps = 5378
# finished. steps = 4346. Current max Steps = 5378
# finished. steps = 4338. Current max Steps = 5378
# finished. steps = 4366. Current max Steps = 5378
# finished. steps = 4514. Current max Steps = 5378
# finished. steps = 4606. Current max Steps = 5378
# finished. steps = 4754. Current max Steps = 5378
# finished. steps = 4462. Current max Steps = 5378
# finished. steps = 4610. Current max Steps = 5378
# finished. steps = 4310. Current max Steps = 5378
# finished. steps = 4718. Current max Steps = 5378
# finished. steps = 4314. Current max Steps = 5378
# finished. steps = 4386. Current max Steps = 5378
# finished. steps = 4254. Current max Steps = 5378
# finished. steps = 4474. Current max Steps = 5378
# finished. steps = 4502. Current max Steps = 5378
# finished. steps = 4650. Current max Steps = 5378
# finished. steps = 4274. Current max Steps = 5378
# finished. steps = 4346. Current max Steps = 5378
# finished. steps = 4338. Current max Steps = 5378
# finished. steps = 4330. Current max Steps = 5378
# finished. steps = 4358. Current max Steps = 5378
# finished. steps = 4506. Current max Steps = 5378
# finished. steps = 4722. Current max Steps = 5378
# finished. steps = 4794. Current max Steps = 5378
# finished. steps = 4662. Current max Steps = 5378
# finished. steps = 4638. Current max Steps = 5378
# finished. steps = 4530. Current max Steps = 5378
# finished. steps = 4602. Current max Steps = 5378
# finished. steps = 4534. Current max Steps = 5378
# finished. steps = 4606. Current max Steps = 5378
# finished. steps = 4474. Current max Steps = 5378
# finished. steps = 4486. Current max Steps = 5378
# finished. steps = 4558. Current max Steps = 5378
# finished. steps = 4426. Current max Steps = 5378
# finished. steps = 4082. Current max Steps = 5378
# finished. steps = 4646. Current max Steps = 5378
# finished. steps = 4302. Current max Steps = 5378
# finished. steps = 4330. Current max Steps = 5378
# finished. steps = 4478. Current max Steps = 5378
# finished. steps = 4194. Current max Steps = 5378
# finished. steps = 4222. Current max Steps = 5378
# finished. steps = 4370. Current max Steps = 5378
# finished. steps = 4158. Current max Steps = 5378
# finished. steps = 4306. Current max Steps = 5378
# finished. steps = 4446. Current max Steps = 5378
# finished. steps = 4266. Current max Steps = 5378
# finished. steps = 4294. Current max Steps = 5378
# finished. steps = 4442. Current max Steps = 5378
# finished. steps = 4230. Current max Steps = 5378
# finished. steps = 4378. Current max Steps = 5378
# finished. steps = 4518. Current max Steps = 5378
# finished. steps = 4222. Current max Steps = 5378
# finished. steps = 4370. Current max Steps = 5378
# finished. steps = 4510. Current max Steps = 5378
# finished. steps = 4502. Current max Steps = 5378
# finished. steps = 4434. Current max Steps = 5378
# finished. steps = 4394. Current max Steps = 5378
# finished. steps = 4762. Current max Steps = 5378
# finished. steps = 4722. Current max Steps = 5378
# finished. steps = 5170. Current max Steps = 5378
# finished. steps = 4966. Current max Steps = 5378
# finished. steps = 4978. Current max Steps = 5378
# finished. steps = 4982. Current max Steps = 5378
# finished. steps = 4410. Current max Steps = 5378
# finished. steps = 4934. Current max Steps = 5378
# finished. steps = 4370. Current max Steps = 5378
# finished. steps = 4638. Current max Steps = 5378
# finished. steps = 4630. Current max Steps = 5378
# finished. steps = 4658. Current max Steps = 5378
# finished. steps = 4806. Current max Steps = 5378
# finished. steps = 4642. Current max Steps = 5378
# finished. steps = 4670. Current max Steps = 5378
# finished. steps = 4818. Current max Steps = 5378
# finished. steps = 4606. Current max Steps = 5378
# finished. steps = 4754. Current max Steps = 5378
# finished. steps = 4894. Current max Steps = 5378
# finished. steps = 4718. Current max Steps = 5378
# finished. steps = 4866. Current max Steps = 5378
# finished. steps = 4702. Current max Steps = 5378
# finished. steps = 5110. Current max Steps = 5378
# finished. steps = 4754. Current max Steps = 5378
# finished. steps = 4902. Current max Steps = 5378
# finished. steps = 4766. Current max Steps = 5378
# finished. steps = 4914. Current max Steps = 5378
# finished. steps = 4702. Current max Steps = 5378
# finished. steps = 4850. Current max Steps = 5378
# finished. steps = 4594. Current max Steps = 5378
# finished. steps = 4402. Current max Steps = 5378
# finished. steps = 4926. Current max Steps = 5378
# finished. steps = 4362. Current max Steps = 5378
# finished. steps = 4630. Current max Steps = 5378
# finished. steps = 4622. Current max Steps = 5378
# finished. steps = 4650. Current max Steps = 5378
# finished. steps = 4798. Current max Steps = 5378
# finished. steps = 4634. Current max Steps = 5378
# finished. steps = 4662. Current max Steps = 5378
# finished. steps = 4810. Current max Steps = 5378
# finished. steps = 4598. Current max Steps = 5378
# finished. steps = 4746. Current max Steps = 5378
# finished. steps = 4886. Current max Steps = 5378
# finished. steps = 4810. Current max Steps = 5378
# finished. steps = 4726. Current max Steps = 5378
# finished. steps = 4606. Current max Steps = 5378
# finished. steps = 4618. Current max Steps = 5378
# finished. steps = 4622. Current max Steps = 5378
# finished. steps = 4574. Current max Steps = 5378
# finished. steps = 4170. Current max Steps = 5378
# finished. steps = 4390. Current max Steps = 5378
# finished. steps = 4418. Current max Steps = 5378
# finished. steps = 4566. Current max Steps = 5378
# finished. steps = 4278. Current max Steps = 5378
# finished. steps = 4270. Current max Steps = 5378
# finished. steps = 4298. Current max Steps = 5378
# finished. steps = 4446. Current max Steps = 5378
# finished. steps = 4282. Current max Steps = 5378
# finished. steps = 4310. Current max Steps = 5378
# finished. steps = 4458. Current max Steps = 5378
# finished. steps = 4246. Current max Steps = 5378
# finished. steps = 4394. Current max Steps = 5378
# finished. steps = 4534. Current max Steps = 5378
# finished. steps = 4514. Current max Steps = 5378
# finished. steps = 4662. Current max Steps = 5378
# finished. steps = 4802. Current max Steps = 5378
# finished. steps = 4794. Current max Steps = 5378
# finished. steps = 4806. Current max Steps = 5378
# finished. steps = 4154. Current max Steps = 5378
# finished. steps = 4114. Current max Steps = 5378
# finished. steps = 4274. Current max Steps = 5378
# finished. steps = 4234. Current max Steps = 5378
# finished. steps = 4266. Current max Steps = 5378
# finished. steps = 4226. Current max Steps = 5378
# finished. steps = 4674. Current max Steps = 5378
# finished. steps = 4470. Current max Steps = 5378
# finished. steps = 4482. Current max Steps = 5378
# finished. steps = 4486. Current max Steps = 5378
# finished. steps = 3914. Current max Steps = 5378
# finished. steps = 4438. Current max Steps = 5378
# finished. steps = 3874. Current max Steps = 5378
# finished. steps = 4142. Current max Steps = 5378
# finished. steps = 4134. Current max Steps = 5378
# finished. steps = 4162. Current max Steps = 5378
# finished. steps = 4310. Current max Steps = 5378
# finished. steps = 4146. Current max Steps = 5378
# finished. steps = 4174. Current max Steps = 5378
# finished. steps = 4322. Current max Steps = 5378
# finished. steps = 4110. Current max Steps = 5378
# finished. steps = 4258. Current max Steps = 5378
# finished. steps = 4398. Current max Steps = 5378
# finished. steps = 5442. Current max Steps = 5442
# finished. steps = 5298. Current max Steps = 5442
# finished. steps = 4946. Current max Steps = 5442
# finished. steps = 5018. Current max Steps = 5442
# finished. steps = 4886. Current max Steps = 5442
# finished. steps = 5106. Current max Steps = 5442
# finished. steps = 5134. Current max Steps = 5442
# finished. steps = 5282. Current max Steps = 5442
# finished. steps = 4906. Current max Steps = 5442
# finished. steps = 4978. Current max Steps = 5442
# finished. steps = 4970. Current max Steps = 5442
# finished. steps = 4962. Current max Steps = 5442
# finished. steps = 4990. Current max Steps = 5442
# finished. steps = 5138. Current max Steps = 5442
# finished. steps = 5230. Current max Steps = 5442
# finished. steps = 5378. Current max Steps = 5442
# finished. steps = 5086. Current max Steps = 5442
# finished. steps = 5234. Current max Steps = 5442
# finished. steps = 4934. Current max Steps = 5442
# finished. steps = 5342. Current max Steps = 5442
# finished. steps = 4938. Current max Steps = 5442
# finished. steps = 5010. Current max Steps = 5442
# finished. steps = 4878. Current max Steps = 5442
# finished. steps = 5098. Current max Steps = 5442
# finished. steps = 5126. Current max Steps = 5442
# finished. steps = 5274. Current max Steps = 5442
# finished. steps = 4898. Current max Steps = 5442
# finished. steps = 4970. Current max Steps = 5442
# finished. steps = 4962. Current max Steps = 5442
# finished. steps = 4954. Current max Steps = 5442
# finished. steps = 4982. Current max Steps = 5442
# finished. steps = 5130. Current max Steps = 5442
# finished. steps = 5346. Current max Steps = 5442
# finished. steps = 5418. Current max Steps = 5442
# finished. steps = 5286. Current max Steps = 5442
# finished. steps = 5262. Current max Steps = 5442
# finished. steps = 5154. Current max Steps = 5442
# finished. steps = 5226. Current max Steps = 5442
# finished. steps = 5158. Current max Steps = 5442
# finished. steps = 5230. Current max Steps = 5442
# finished. steps = 5098. Current max Steps = 5442
# finished. steps = 5110. Current max Steps = 5442
# finished. steps = 5182. Current max Steps = 5442
# finished. steps = 5050. Current max Steps = 5442
# finished. steps = 4706. Current max Steps = 5442
# finished. steps = 5270. Current max Steps = 5442
# finished. steps = 4926. Current max Steps = 5442
# finished. steps = 4954. Current max Steps = 5442
# finished. steps = 5102. Current max Steps = 5442
# finished. steps = 4818. Current max Steps = 5442
# finished. steps = 4846. Current max Steps = 5442
# finished. steps = 4994. Current max Steps = 5442
# finished. steps = 4782. Current max Steps = 5442
# finished. steps = 4930. Current max Steps = 5442
# finished. steps = 5070. Current max Steps = 5442
# finished. steps = 4890. Current max Steps = 5442
# finished. steps = 4918. Current max Steps = 5442
# finished. steps = 5066. Current max Steps = 5442
# finished. steps = 4854. Current max Steps = 5442
# finished. steps = 5002. Current max Steps = 5442
# finished. steps = 5142. Current max Steps = 5442
# finished. steps = 4846. Current max Steps = 5442
# finished. steps = 4994. Current max Steps = 5442
# finished. steps = 5134. Current max Steps = 5442
# finished. steps = 5126. Current max Steps = 5442
# finished. steps = 4946. Current max Steps = 5442
# finished. steps = 4802. Current max Steps = 5442
# finished. steps = 4450. Current max Steps = 5442
# finished. steps = 4522. Current max Steps = 5442
# finished. steps = 4390. Current max Steps = 5442
# finished. steps = 4610. Current max Steps = 5442
# finished. steps = 4638. Current max Steps = 5442
# finished. steps = 4786. Current max Steps = 5442
# finished. steps = 4410. Current max Steps = 5442
# finished. steps = 4482. Current max Steps = 5442
# finished. steps = 4474. Current max Steps = 5442
# finished. steps = 4466. Current max Steps = 5442
# finished. steps = 4494. Current max Steps = 5442
# finished. steps = 4642. Current max Steps = 5442
# finished. steps = 4898. Current max Steps = 5442
# finished. steps = 4858. Current max Steps = 5442
# finished. steps = 4890. Current max Steps = 5442
# finished. steps = 4850. Current max Steps = 5442
# finished. steps = 5298. Current max Steps = 5442
# finished. steps = 5094. Current max Steps = 5442
# finished. steps = 5106. Current max Steps = 5442
# finished. steps = 5110. Current max Steps = 5442
# finished. steps = 4538. Current max Steps = 5442
# finished. steps = 5062. Current max Steps = 5442
# finished. steps = 4498. Current max Steps = 5442
# finished. steps = 4766. Current max Steps = 5442
# finished. steps = 4758. Current max Steps = 5442
# finished. steps = 4786. Current max Steps = 5442
# finished. steps = 4934. Current max Steps = 5442
# finished. steps = 4770. Current max Steps = 5442
# finished. steps = 4798. Current max Steps = 5442
# finished. steps = 4946. Current max Steps = 5442
# finished. steps = 4734. Current max Steps = 5442
# finished. steps = 4882. Current max Steps = 5442
# finished. steps = 5022. Current max Steps = 5442
# finished. steps = 4402. Current max Steps = 5442
# finished. steps = 4362. Current max Steps = 5442
# finished. steps = 5570. Current max Steps = 5570
# finished. steps = 5426. Current max Steps = 5570
# finished. steps = 5074. Current max Steps = 5570
# finished. steps = 5146. Current max Steps = 5570
# finished. steps = 5014. Current max Steps = 5570
# finished. steps = 5234. Current max Steps = 5570
# finished. steps = 5262. Current max Steps = 5570
# finished. steps = 5410. Current max Steps = 5570
# finished. steps = 5034. Current max Steps = 5570
# finished. steps = 5106. Current max Steps = 5570
# finished. steps = 5098. Current max Steps = 5570
# finished. steps = 5090. Current max Steps = 5570
# finished. steps = 5118. Current max Steps = 5570
# finished. steps = 5266. Current max Steps = 5570
# finished. steps = 5026. Current max Steps = 5570
# finished. steps = 4986. Current max Steps = 5570
# Done. Max Steps = 5570

# %%
print(len(nodes))
print(len(cache))
# 141*141/2
node_grid = grid[:]
for coords in nodes:
    node_grid[coords[0]][coords[1]] = 'O'
print_grid(node_grid)
[print(x) for x in nodes]
print(nodes)
A = [1,2,3,4]
print(A)
A.remove(3)
end_node
# Out:
# 9
# 0
# #O#####################
# #.......#########...###
# #######.#########.#.###
# ###.....#.>O>.###.#.###
# ###v#####.#v#.###.#.###
# ###O>...#.#.#.....#...#
# ###v###.#.#.#########.#
# ###...#.#.#.......#...#
# #####.#.#.#######.#.###
# #.....#.#.#.......#...#
# #.#####.#.#.#########v#
# #.#...#...#...###...>O#
# #.#.#v#######v###.###v#
# #...#O>.#...>O>.#.###.#
# #####v#.#.###v#.#.###.#
# #.....#...#...#.#.#...#
# #.#########.###.#.#.###
# #...###...#...#...#.###
# ###.###.#.###v#####v###
# #...#...#.#.>O>.#.>O###
# #.###.###.#.###.#.#v###
# #.....###...###...#...#
# #####################O#
# (5, 3)
# (0, 1)
# (13, 5)
# (3, 11)
# (19, 13)
# (13, 13)
# (11, 21)
# (19, 19)
# (22, 21)
# {(5, 3): {(3, 11): 22, (0, 1): 15, (13, 5): 22}, (0, 1): {(5, 3): 15}, (13, 5): {(13, 13): 12, (5, 3): 22, (19, 13): 38}, (3, 11): {(11, 21): 30, (13, 13): 24}, (19, 13): {(19, 19): 10, (13, 13): 10}, (13, 13): {(13, 5): 12, (3, 11): 24, (19, 13): 10, (11, 21): 18}, (11, 21): {(3, 11): 30, (13, 13): 18, (19, 19): 10}, (19, 19): {(22, 21): 5, (19, 13): 10, (11, 21): 10}, (22, 21): {(19, 19): 5}}
# [1, 2, 3, 4]
# (22, 21)
