# %%
# Part 1
def print_grid(grid):
    # print(grid)
    print('grid = ')
    [print(''.join(x)) for x in grid]
    print(' ')

def move(coords,dir,calls):
    calls += 1
    if calls > 20:
        z
    print(coords,dir)
    # move until the same coord, dir is reached, or until the beam leaves the gridrid
    if (coords[0] == 0 and dir == 'N') | (coords[0] == Y-1 and dir == 'S') | (coords[1] == 0 and dir == 'W') | (coords[1] == X-1 and dir == 'E'):
        print('can go that way')
        return 0

    key = (coords[0],coords[1], dir)
    if key in cache:
        return cache[key]
        
    if dir == 'N':
        coords[0] -= 1
    elif dir == 'E':
        coords[1] += 1
    elif dir == 'S':
        coords[0] += 1
    else:
        coords[0] -= 1

    if grid[coords[0]][coords[1]] == '.':
        move(coords, dir,calls)
    elif grid[coords[0]][coords[1]] == '\\' and dir == 'N':
        move(coords, 'W',calls)
    elif grid[coords[0]][coords[1]] == '\\' and dir == 'E':
        move(coords, 'S',calls)
    elif grid[coords[0]][coords[1]] == '\\' and dir == 'S':
        move(coords, 'E',calls)
    elif grid[coords[0]][coords[1]] == '\\' and dir == 'W':
        move(coords, 'N',calls)
    elif grid[coords[0]][coords[1]] == '/' and dir == 'N':
        move(coords, 'E',calls)
    elif grid[coords[0]][coords[1]] == '/' and dir == 'E':
        move(coords, 'N',calls)
    elif grid[coords[0]][coords[1]] == '/' and dir == 'S':
        move(coords, 'W',calls)
    elif grid[coords[0]][coords[1]] == '/' and dir == 'W':
        move(coords, 'S',calls)
    elif grid[coords[0]][coords[1]] == '-' and dir == 'E':
        move(coords, 'E',calls)
    elif grid[coords[0]][coords[1]] == '-' and dir == 'W':
        move(coords, 'W',calls)
    elif grid[coords[0]][coords[1]] == '-':
        move(coords, 'E',calls)
        move(coords, 'W',calls)
    elif grid[coords[0]][coords[1]] == '|' and dir == 'N':
        move(coords, 'N',calls)
    elif grid[coords[0]][coords[1]] == '|' and dir == 'WS':
        move(coords, 'S',calls)
    elif grid[coords[0]][coords[1]] == '|':
        move(coords, 'N',calls)
        move(coords, 'S',calls)

    cache[key] = 0
    return coords, dir

# main
lines = open("input_16_test.txt").read().splitlines()
grid = [list(x) for x in lines]

X = len(grid)
Y = len(grid[0])
print_grid(grid)

cache = {}
calls = 0
done = False
move([0,-1],'E',calls)
# while not done:
#     print(cache)
# Out:
# grid =
# .|...\....
# |.-.\.....
# .....|-...
# ........|.
# ..........
# .........\
# ..../.\\..
# .-.-/..|..
# .|....-|.\
# ..//.|....
#
# [0, -1] E
# [0, 0] E
# [0, 1] N
# can go that way
# [0, 1] S
# [1, 1] S
# [2, 1] S
# [3, 1] S
# [4, 1] S
# [5, 1] S
# [6, 1] S
# [7, 1] E
# [7, 2] E
# [7, 3] E
# [7, 4] N
# [6, 4] N
# [5, 4] N
# [4, 4] N
# [3, 4] N
# [2, 4] N
# [1, 4] S
# [2, 4] S
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 66
#      64 calls = 0
#      65 done = False
# ---> 66 move([0,-1],'E',calls)
#      67 # while not done:
#      68 #     print(cache)
#
# Cell In[65], line 32, in move(coords, dir, calls)
#      29     coords[0] -= 1
#      31 if grid[coords[0]][coords[1]] == '.':
# ---> 32     move(coords, dir,calls)
#      33 elif grid[coords[0]][coords[1]] == '\\':
#      34     move(coords, 'S',calls)
#
# ...

# %%
coords = [1,4]
print(coords)
print(grid[1][4])
# grid(coords[0],coords[1])
print(coords[0],coords[1])
print(grid[coords[0]][coords[1]])
grid[coords[0]][coords[1]]

grid[1][4] == '\\'
grid[1][4]
# grid[9][2]
a=5
b='hi'
a==5 and b=='h'
cach = {(a,'hi'):13}
(a,'hi') in cach
# Out:
# [1, 4]
# \
# 1 4
# \
# True
